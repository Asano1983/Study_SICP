# %% [markdown]
# # 3 word2vec
#
# ## 7.3 seq2seqの実装
#
# seq2seqは2つのRNNを組み合わせたニューラルネットワークである。
# その2つのRNNをEncoderクラスとDecoderクラスとしてそれぞれ実装する。
# そして、その2つのクラスを組み合わせて、Seq2seqクラスを実装する。
#
# ### 7.3.1Encoderクラス
#
# まずEncoderクラスを実装する（図7-15を見るのが分かりやすい）。

# %%
import sys
sys.path.append('..')
from common.time_layers import *
from common.base_model import BaseModel

# %%
class Encoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=False) # 状態を維持しない

        self.params = self.embed.params + self.lstm.params
        self.grads = self.embed.grads + self.lstm.grads
        self.hs = None

    def forward(self, xs):
        xs = self.embed.forward(xs)
        hs = self.lstm.forward(xs)
        self.hs = hs
        return hs[:, -1, :]

    def backward(self, dh):
        dhs = np.zeros_like(self.hs)
        dhs[:, -1, :] = dh

        dout = self.lstm.backward(dhs)
        dout = self.embed.backward(dout)
        return dout

# %% [markdown]
# 注１：今回は0から9の数字と「+」と「 」（空白文字）と「 _ 」の計１３文字を扱うため、vocab_sizeは13になる。
#
# 注２：5章と6章の言語モデルでは「長い時系列データ」がひとつだけ存在する問題として扱った。
# そこではstateful=Trueとして隠れ状態を維持した。
# 今回は「短い時系列データ」が複数存在する問題なので、問題ごとにLSTMの隠れ状態をリセットする。
#
# ### 7.3.2 Decoderクラス
#
# 次にDecoderを実装しよう。
# 学習時のレイヤ構成は図7-17に書いてある。
# 今回の問題は足し算なので、決定的に答えを生成したい。
# そのため生成時にはargmaxノードを使う（図7-18）。
#
# このように学習時と生成時でレイヤ構成が異なるのでDecoderクラスはTime Softmax with Lossレイヤの前までを担当することにする（図7-19）。

# %%
class Decoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True) # Encoderのhを維持する。
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []
        for layer in (self.embed, self.lstm, self.affine):
            self.params += layer.params
            self.grads += layer.grads

    def forward(self, xs, h):
        self.lstm.set_state(h)

        out = self.embed.forward(xs)
        out = self.lstm.forward(out)
        score = self.affine.forward(out)
        return score

    def backward(self, dscore):
        dout = self.affine.backward(dscore)
        dout = self.lstm.backward(dout)
        dout = self.embed.backward(dout)
        dh = self.lstm.dh
        return dh

    def generate(self, h, start_id, sample_size):
        sampled = []
        sample_id = start_id
        self.lstm.set_state(h)

        for _ in range(sample_size):
            x = np.array(sample_id).reshape((1, 1))
            out = self.embed.forward(x)
            out = self.lstm.forward(out)
            score = self.affine.forward(out)

            sample_id = np.argmax(score.flatten())
            sampled.append(int(sample_id))

        return sampled

# %% [markdown]
# ### 7.3.3 Seq2seqクラス
#
# Seq2seqは繋ぎ合わせるだけ。

# %%
class Seq2seq(BaseModel):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = Encoder(V, D, H)
        self.decoder = Decoder(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads

    def forward(self, xs, ts):
        decoder_xs, decoder_ts = ts[:, :-1], ts[:, 1:]

        h = self.encoder.forward(xs)
        score = self.decoder.forward(decoder_xs, h)
        loss = self.softmax.forward(score, decoder_ts)
        return loss

    def backward(self, dout=1):
        dout = self.softmax.backward(dout)
        dh = self.decoder.backward(dout)
        dout = self.encoder.backward(dh)
        return dout

    def generate(self, xs, start_id, sample_size):
        h = self.encoder.forward(xs)
        sampled = self.decoder.generate(h, start_id, sample_size)
        return sampled

# %% [markdown]
# ### 7.3.4 seq2seqの評価

# %%
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
#from seq2seq import Seq2seq
#from peeky_seq2seq import PeekySeq2seq


# データセットの読み込み
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

# Reverse input? =================================================
is_reverse = False  # True
if is_reverse:
    x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]
# ================================================================

# ハイパーパラメータの設定
vocab_size = len(char_to_id)
wordvec_size = 16
hideen_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

# Normal or Peeky? ==============================================
model = Seq2seq(vocab_size, wordvec_size, hideen_size)
# model = PeekySeq2seq(vocab_size, wordvec_size, hideen_size)
# ================================================================
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1,
                batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct,
                                    id_to_char, verbose, is_reverse)

    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('val acc %.3f%%' % (acc * 100))
# Out:
# | epoch 1 |  iter 1 / 351 | time 0[s] | loss 2.56
# | epoch 1 |  iter 21 / 351 | time 3[s] | loss 2.53
# | epoch 1 |  iter 41 / 351 | time 5[s] | loss 2.17
# | epoch 1 |  iter 61 / 351 | time 8[s] | loss 1.96
# | epoch 1 |  iter 81 / 351 | time 11[s] | loss 1.92
# | epoch 1 |  iter 101 / 351 | time 14[s] | loss 1.87
# | epoch 1 |  iter 121 / 351 | time 17[s] | loss 1.85
# | epoch 1 |  iter 141 / 351 | time 20[s] | loss 1.83
# | epoch 1 |  iter 161 / 351 | time 23[s] | loss 1.79
# | epoch 1 |  iter 181 / 351 | time 26[s] | loss 1.77
# | epoch 1 |  iter 201 / 351 | time 29[s] | loss 1.77
# | epoch 1 |  iter 221 / 351 | time 32[s] | loss 1.76
# | epoch 1 |  iter 241 / 351 | time 34[s] | loss 1.76
# | epoch 1 |  iter 261 / 351 | time 37[s] | loss 1.76
# | epoch 1 |  iter 281 / 351 | time 40[s] | loss 1.75
# | epoch 1 |  iter 301 / 351 | time 43[s] | loss 1.74
# | epoch 1 |  iter 321 / 351 | time 46[s] | loss 1.75
# | epoch 1 |  iter 341 / 351 | time 49[s] | loss 1.74
# Q 77+85
# T 162
# X 100
# ---
# Q 975+164
# T 1139
# X 1000
# ---
# Q 582+84
# T 666
# X 1000
# ---
# Q 8+155
# T 163
# X 100
# ---
# Q 367+55
# T 422
# X 1000
# ---
# Q 600+257
# T 857
# X 1000
# ---
# Q 761+292
# T 1053
# X 1000
# ---
# Q 830+597
# T 1427
# X 1000
# ---
# Q 26+838
# T 864
# X 1000
# ---
# Q 143+93
# T 236
# X 100
# ---
# val acc 0.180%
# | epoch 2 |  iter 1 / 351 | time 0[s] | loss 1.74
# | epoch 2 |  iter 21 / 351 | time 3[s] | loss 1.73
# | epoch 2 |  iter 41 / 351 | time 5[s] | loss 1.74
# | epoch 2 |  iter 61 / 351 | time 8[s] | loss 1.74
# | epoch 2 |  iter 81 / 351 | time 11[s] | loss 1.73
# | epoch 2 |  iter 101 / 351 | time 14[s] | loss 1.73
# | epoch 2 |  iter 121 / 351 | time 17[s] | loss 1.72
# | epoch 2 |  iter 141 / 351 | time 20[s] | loss 1.71
# | epoch 2 |  iter 161 / 351 | time 23[s] | loss 1.71
# | epoch 2 |  iter 181 / 351 | time 26[s] | loss 1.71
# | epoch 2 |  iter 201 / 351 | time 29[s] | loss 1.70
# | epoch 2 |  iter 221 / 351 | time 32[s] | loss 1.71
# | epoch 2 |  iter 241 / 351 | time 35[s] | loss 1.70
# | epoch 2 |  iter 261 / 351 | time 38[s] | loss 1.69
# | epoch 2 |  iter 281 / 351 | time 40[s] | loss 1.69
# | epoch 2 |  iter 301 / 351 | time 43[s] | loss 1.69
# | epoch 2 |  iter 321 / 351 | time 46[s] | loss 1.68
# | epoch 2 |  iter 341 / 351 | time 49[s] | loss 1.67
# Q 77+85
# T 162
# X 994
# ---
# Q 975+164
# T 1139
# X 1000
# ---
# Q 582+84
# T 666
# X 700
# ---
# Q 8+155
# T 163
# X 100
# ---
# Q 367+55
# T 422
# X 400
# ---
# Q 600+257
# T 857
# X 1000
# ---
# Q 761+292
# T 1053
# X 1000
# ---
# Q 830+597
# T 1427
# X 1544
# ---
# Q 26+838
# T 864
# X 400
# ---
# Q 143+93
# T 236
# X 400
# ---
# val acc 0.220%
# | epoch 3 |  iter 1 / 351 | time 0[s] | loss 1.66
# | epoch 3 |  iter 21 / 351 | time 3[s] | loss 1.66
# | epoch 3 |  iter 41 / 351 | time 5[s] | loss 1.65
# | epoch 3 |  iter 61 / 351 | time 8[s] | loss 1.63
# | epoch 3 |  iter 81 / 351 | time 11[s] | loss 1.62
# | epoch 3 |  iter 101 / 351 | time 14[s] | loss 1.62
# | epoch 3 |  iter 121 / 351 | time 17[s] | loss 1.60
# | epoch 3 |  iter 141 / 351 | time 20[s] | loss 1.59
# | epoch 3 |  iter 161 / 351 | time 23[s] | loss 1.57
# | epoch 3 |  iter 181 / 351 | time 26[s] | loss 1.57
# | epoch 3 |  iter 201 / 351 | time 29[s] | loss 1.56
# | epoch 3 |  iter 221 / 351 | time 32[s] | loss 1.54
# | epoch 3 |  iter 241 / 351 | time 35[s] | loss 1.52
# | epoch 3 |  iter 261 / 351 | time 38[s] | loss 1.52
# | epoch 3 |  iter 281 / 351 | time 41[s] | loss 1.52
# | epoch 3 |  iter 301 / 351 | time 43[s] | loss 1.50
# | epoch 3 |  iter 321 / 351 | time 46[s] | loss 1.49
# | epoch 3 |  iter 341 / 351 | time 49[s] | loss 1.48
# Q 77+85
# T 162
# X 108
# ---
# Q 975+164
# T 1139
# X 1001
# ---
# Q 582+84
# T 666
# X 648
# ---
# Q 8+155
# T 163
# X 138
# ---
# Q 367+55
# T 422
# X 448
# ---
# Q 600+257
# T 857
# X 848
# ---
# Q 761+292
# T 1053
# X 1011
# ---
# Q 830+597
# T 1427
# X 1373
# ---
# Q 26+838
# T 864
# X 868
# ---
# Q 143+93
# T 236
# X 348
# ---
# val acc 0.560%
# | epoch 4 |  iter 1 / 351 | time 0[s] | loss 1.47
# | epoch 4 |  iter 21 / 351 | time 3[s] | loss 1.46
# | epoch 4 |  iter 41 / 351 | time 5[s] | loss 1.44
# | epoch 4 |  iter 61 / 351 | time 8[s] | loss 1.43
# | epoch 4 |  iter 81 / 351 | time 11[s] | loss 1.42
# | epoch 4 |  iter 101 / 351 | time 14[s] | loss 1.41
# | epoch 4 |  iter 121 / 351 | time 17[s] | loss 1.40
# | epoch 4 |  iter 141 / 351 | time 20[s] | loss 1.40
# | epoch 4 |  iter 161 / 351 | time 23[s] | loss 1.38
# | epoch 4 |  iter 181 / 351 | time 26[s] | loss 1.38
# | epoch 4 |  iter 201 / 351 | time 29[s] | loss 1.37
# | epoch 4 |  iter 221 / 351 | time 33[s] | loss 1.35
# | epoch 4 |  iter 241 / 351 | time 36[s] | loss 1.33
# | epoch 4 |  iter 261 / 351 | time 39[s] | loss 1.33
# | epoch 4 |  iter 281 / 351 | time 42[s] | loss 1.33
# | epoch 4 |  iter 301 / 351 | time 44[s] | loss 1.32
# | epoch 4 |  iter 321 / 351 | time 47[s] | loss 1.31
# | epoch 4 |  iter 341 / 351 | time 50[s] | loss 1.30
# Q 77+85
# T 162
# X 146
# ---
# Q 975+164
# T 1139
# X 1189
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 432
# ---
# Q 600+257
# T 857
# X 866
# ---
# Q 761+292
# T 1053
# X 1002
# ---
# Q 830+597
# T 1427
# X 1406
# ---
# Q 26+838
# T 864
# X 862
# ---
# Q 143+93
# T 236
# X 202
# ---
# val acc 1.060%
# | epoch 5 |  iter 1 / 351 | time 0[s] | loss 1.28
# | epoch 5 |  iter 21 / 351 | time 3[s] | loss 1.29
# | epoch 5 |  iter 41 / 351 | time 6[s] | loss 1.28
# | epoch 5 |  iter 61 / 351 | time 8[s] | loss 1.27
# | epoch 5 |  iter 81 / 351 | time 11[s] | loss 1.27
# | epoch 5 |  iter 101 / 351 | time 14[s] | loss 1.26
# | epoch 5 |  iter 121 / 351 | time 17[s] | loss 1.26
# | epoch 5 |  iter 141 / 351 | time 20[s] | loss 1.27
# | epoch 5 |  iter 161 / 351 | time 23[s] | loss 1.26
# | epoch 5 |  iter 181 / 351 | time 26[s] | loss 1.25
# | epoch 5 |  iter 201 / 351 | time 29[s] | loss 1.23
# | epoch 5 |  iter 221 / 351 | time 31[s] | loss 1.22
# | epoch 5 |  iter 241 / 351 | time 34[s] | loss 1.21
# | epoch 5 |  iter 261 / 351 | time 37[s] | loss 1.21
# | epoch 5 |  iter 281 / 351 | time 40[s] | loss 1.21
# | epoch 5 |  iter 301 / 351 | time 43[s] | loss 1.20
# | epoch 5 |  iter 321 / 351 | time 46[s] | loss 1.19
# | epoch 5 |  iter 341 / 351 | time 49[s] | loss 1.18
# Q 77+85
# T 162
# X 145
# ---
# Q 975+164
# T 1139
# X 1168
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 192
# ---
# Q 367+55
# T 422
# X 431
# ---
# Q 600+257
# T 857
# X 895
# ---
# Q 761+292
# T 1053
# X 1015
# ---
# Q 830+597
# T 1427
# X 1493
# ---
# Q 26+838
# T 864
# X 891
# ---
# Q 143+93
# T 236
# X 221
# ---
# val acc 2.260%
# | epoch 6 |  iter 1 / 351 | time 0[s] | loss 1.17
# | epoch 6 |  iter 21 / 351 | time 3[s] | loss 1.17
# | epoch 6 |  iter 41 / 351 | time 5[s] | loss 1.18
# | epoch 6 |  iter 61 / 351 | time 8[s] | loss 1.17
# | epoch 6 |  iter 81 / 351 | time 11[s] | loss 1.16
# | epoch 6 |  iter 101 / 351 | time 14[s] | loss 1.16
# | epoch 6 |  iter 121 / 351 | time 17[s] | loss 1.16
# | epoch 6 |  iter 141 / 351 | time 20[s] | loss 1.14
# | epoch 6 |  iter 161 / 351 | time 23[s] | loss 1.14
# | epoch 6 |  iter 181 / 351 | time 26[s] | loss 1.13
# | epoch 6 |  iter 201 / 351 | time 29[s] | loss 1.15
# | epoch 6 |  iter 221 / 351 | time 31[s] | loss 1.13
# | epoch 6 |  iter 241 / 351 | time 34[s] | loss 1.13
# | epoch 6 |  iter 261 / 351 | time 37[s] | loss 1.11
# | epoch 6 |  iter 281 / 351 | time 40[s] | loss 1.12
# | epoch 6 |  iter 301 / 351 | time 43[s] | loss 1.12
# | epoch 6 |  iter 321 / 351 | time 46[s] | loss 1.11
# | epoch 6 |  iter 341 / 351 | time 49[s] | loss 1.10
# Q 77+85
# T 162
# X 166
# ---
# Q 975+164
# T 1139
# X 1168
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# X 168
# ---
# Q 367+55
# T 422
# X 441
# ---
# Q 600+257
# T 857
# X 875
# ---
# Q 761+292
# T 1053
# X 1112
# ---
# Q 830+597
# T 1427
# X 1418
# ---
# Q 26+838
# T 864
# X 875
# ---
# Q 143+93
# T 236
# X 207
# ---
# val acc 2.520%
# | epoch 7 |  iter 1 / 351 | time 0[s] | loss 1.13
# | epoch 7 |  iter 21 / 351 | time 3[s] | loss 1.09
# | epoch 7 |  iter 41 / 351 | time 5[s] | loss 1.09
# | epoch 7 |  iter 61 / 351 | time 8[s] | loss 1.09
# | epoch 7 |  iter 81 / 351 | time 11[s] | loss 1.08
# | epoch 7 |  iter 101 / 351 | time 14[s] | loss 1.08
# | epoch 7 |  iter 121 / 351 | time 17[s] | loss 1.08
# | epoch 7 |  iter 141 / 351 | time 20[s] | loss 1.09
# | epoch 7 |  iter 161 / 351 | time 23[s] | loss 1.10
# | epoch 7 |  iter 181 / 351 | time 26[s] | loss 1.12
# | epoch 7 |  iter 201 / 351 | time 29[s] | loss 1.11
# | epoch 7 |  iter 221 / 351 | time 31[s] | loss 1.10
# | epoch 7 |  iter 241 / 351 | time 34[s] | loss 1.08
# | epoch 7 |  iter 261 / 351 | time 37[s] | loss 1.07
# | epoch 7 |  iter 281 / 351 | time 40[s] | loss 1.06
# | epoch 7 |  iter 301 / 351 | time 43[s] | loss 1.07
# | epoch 7 |  iter 321 / 351 | time 46[s] | loss 1.05
# | epoch 7 |  iter 341 / 351 | time 49[s] | loss 1.05
# Q 77+85
# T 162
# X 166
# ---
# Q 975+164
# T 1139
# X 1166
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# X 161
# ---
# Q 367+55
# T 422
# X 418
# ---
# Q 600+257
# T 857
# X 864
# ---
# Q 761+292
# T 1053
# X 1056
# ---
# Q 830+597
# T 1427
# X 1460
# ---
# Q 26+838
# T 864
# X 867
# ---
# Q 143+93
# T 236
# X 227
# ---
# val acc 2.760%
# | epoch 8 |  iter 1 / 351 | time 0[s] | loss 1.09
# | epoch 8 |  iter 21 / 351 | time 3[s] | loss 1.04
# | epoch 8 |  iter 41 / 351 | time 5[s] | loss 1.04
# | epoch 8 |  iter 61 / 351 | time 8[s] | loss 1.04
# | epoch 8 |  iter 81 / 351 | time 11[s] | loss 1.07
# | epoch 8 |  iter 101 / 351 | time 14[s] | loss 1.05
# | epoch 8 |  iter 121 / 351 | time 17[s] | loss 1.04
# | epoch 8 |  iter 141 / 351 | time 20[s] | loss 1.04
# | epoch 8 |  iter 161 / 351 | time 23[s] | loss 1.08
# | epoch 8 |  iter 181 / 351 | time 26[s] | loss 1.03
# | epoch 8 |  iter 201 / 351 | time 28[s] | loss 1.02
# | epoch 8 |  iter 221 / 351 | time 31[s] | loss 1.01
# | epoch 8 |  iter 241 / 351 | time 34[s] | loss 1.01
# | epoch 8 |  iter 261 / 351 | time 37[s] | loss 1.02
# | epoch 8 |  iter 281 / 351 | time 40[s] | loss 1.01
# | epoch 8 |  iter 301 / 351 | time 43[s] | loss 1.01
# | epoch 8 |  iter 321 / 351 | time 46[s] | loss 1.01
# | epoch 8 |  iter 341 / 351 | time 49[s] | loss 1.02
# Q 77+85
# T 162
# X 168
# ---
# Q 975+164
# T 1139
# X 1160
# ---
# Q 582+84
# T 666
# X 668
# ---
# Q 8+155
# T 163
# X 179
# ---
# Q 367+55
# T 422
# X 431
# ---
# Q 600+257
# T 857
# X 874
# ---
# Q 761+292
# T 1053
# X 1070
# ---
# Q 830+597
# T 1427
# X 1449
# ---
# Q 26+838
# T 864
# X 871
# ---
# Q 143+93
# T 236
# X 238
# ---
# val acc 3.220%
# | epoch 9 |  iter 1 / 351 | time 0[s] | loss 1.05
# | epoch 9 |  iter 21 / 351 | time 3[s] | loss 1.04
# | epoch 9 |  iter 41 / 351 | time 5[s] | loss 1.03
# | epoch 9 |  iter 61 / 351 | time 8[s] | loss 1.03
# | epoch 9 |  iter 81 / 351 | time 11[s] | loss 1.03
# | epoch 9 |  iter 101 / 351 | time 14[s] | loss 1.03
# | epoch 9 |  iter 121 / 351 | time 17[s] | loss 1.03
# | epoch 9 |  iter 141 / 351 | time 20[s] | loss 1.03
# | epoch 9 |  iter 161 / 351 | time 23[s] | loss 1.02
# | epoch 9 |  iter 181 / 351 | time 26[s] | loss 1.02
# | epoch 9 |  iter 201 / 351 | time 29[s] | loss 1.02
# | epoch 9 |  iter 221 / 351 | time 34[s] | loss 0.99
# | epoch 9 |  iter 241 / 351 | time 37[s] | loss 1.00
# | epoch 9 |  iter 261 / 351 | time 40[s] | loss 0.99
# | epoch 9 |  iter 281 / 351 | time 43[s] | loss 0.98
# | epoch 9 |  iter 301 / 351 | time 46[s] | loss 0.98
# | epoch 9 |  iter 321 / 351 | time 50[s] | loss 0.99
# | epoch 9 |  iter 341 / 351 | time 53[s] | loss 0.98
# Q 77+85
# T 162
# X 164
# ---
# Q 975+164
# T 1139
# X 1128
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 158
# ---
# Q 367+55
# T 422
# X 418
# ---
# Q 600+257
# T 857
# X 848
# ---
# Q 761+292
# T 1053
# X 1038
# ---
# Q 830+597
# T 1427
# X 1428
# ---
# Q 26+838
# T 864
# X 857
# ---
# Q 143+93
# T 236
# X 228
# ---
# val acc 5.240%
# | epoch 10 |  iter 1 / 351 | time 0[s] | loss 0.95
# | epoch 10 |  iter 21 / 351 | time 3[s] | loss 0.97
# | epoch 10 |  iter 41 / 351 | time 6[s] | loss 0.96
# | epoch 10 |  iter 61 / 351 | time 8[s] | loss 0.98
# | epoch 10 |  iter 81 / 351 | time 11[s] | loss 0.97
# | epoch 10 |  iter 101 / 351 | time 14[s] | loss 0.97
# | epoch 10 |  iter 121 / 351 | time 17[s] | loss 0.99
# | epoch 10 |  iter 141 / 351 | time 20[s] | loss 1.00
# | epoch 10 |  iter 161 / 351 | time 23[s] | loss 0.97
# | epoch 10 |  iter 181 / 351 | time 26[s] | loss 0.99
# | epoch 10 |  iter 201 / 351 | time 29[s] | loss 0.97
# | epoch 10 |  iter 221 / 351 | time 32[s] | loss 0.95
# | epoch 10 |  iter 241 / 351 | time 35[s] | loss 0.95
# | epoch 10 |  iter 261 / 351 | time 38[s] | loss 0.96
# | epoch 10 |  iter 281 / 351 | time 41[s] | loss 0.96
# | epoch 10 |  iter 301 / 351 | time 43[s] | loss 0.98
# | epoch 10 |  iter 321 / 351 | time 46[s] | loss 1.01
# | epoch 10 |  iter 341 / 351 | time 49[s] | loss 0.95
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1160
# ---
# Q 582+84
# T 666
# X 660
# ---
# Q 8+155
# T 163
# X 170
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1039
# ---
# Q 830+597
# T 1427
# X 1409
# ---
# Q 26+838
# T 864
# X 867
# ---
# Q 143+93
# T 236
# X 237
# ---
# val acc 5.880%
# | epoch 11 |  iter 1 / 351 | time 0[s] | loss 0.93
# | epoch 11 |  iter 21 / 351 | time 3[s] | loss 0.94
# | epoch 11 |  iter 41 / 351 | time 5[s] | loss 0.96
# | epoch 11 |  iter 61 / 351 | time 8[s] | loss 0.99
# | epoch 11 |  iter 81 / 351 | time 11[s] | loss 0.98
# | epoch 11 |  iter 101 / 351 | time 14[s] | loss 0.97
# | epoch 11 |  iter 121 / 351 | time 17[s] | loss 0.96
# | epoch 11 |  iter 141 / 351 | time 20[s] | loss 0.93
# | epoch 11 |  iter 161 / 351 | time 23[s] | loss 0.93
# | epoch 11 |  iter 181 / 351 | time 26[s] | loss 0.95
# | epoch 11 |  iter 201 / 351 | time 29[s] | loss 0.95
# | epoch 11 |  iter 221 / 351 | time 32[s] | loss 0.97
# | epoch 11 |  iter 241 / 351 | time 35[s] | loss 0.95
# | epoch 11 |  iter 261 / 351 | time 38[s] | loss 0.94
# | epoch 11 |  iter 281 / 351 | time 40[s] | loss 0.93
# | epoch 11 |  iter 301 / 351 | time 43[s] | loss 0.96
# | epoch 11 |  iter 321 / 351 | time 46[s] | loss 0.94
# | epoch 11 |  iter 341 / 351 | time 49[s] | loss 0.93
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1121
# ---
# Q 582+84
# T 666
# X 668
# ---
# Q 8+155
# T 163
# X 155
# ---
# Q 367+55
# T 422
# X 411
# ---
# Q 600+257
# T 857
# X 846
# ---
# Q 761+292
# T 1053
# X 1038
# ---
# Q 830+597
# T 1427
# X 1402
# ---
# Q 26+838
# T 864
# X 861
# ---
# Q 143+93
# T 236
# X 218
# ---
# val acc 5.920%
# | epoch 12 |  iter 1 / 351 | time 0[s] | loss 0.94
# | epoch 12 |  iter 21 / 351 | time 3[s] | loss 0.92
# | epoch 12 |  iter 41 / 351 | time 6[s] | loss 0.92
# | epoch 12 |  iter 61 / 351 | time 8[s] | loss 0.96
# | epoch 12 |  iter 81 / 351 | time 11[s] | loss 0.91
# | epoch 12 |  iter 101 / 351 | time 14[s] | loss 0.92
# | epoch 12 |  iter 121 / 351 | time 17[s] | loss 0.92
# | epoch 12 |  iter 141 / 351 | time 20[s] | loss 0.93
# | epoch 12 |  iter 161 / 351 | time 23[s] | loss 0.92
# | epoch 12 |  iter 181 / 351 | time 26[s] | loss 0.92
# | epoch 12 |  iter 201 / 351 | time 29[s] | loss 0.92
# | epoch 12 |  iter 221 / 351 | time 32[s] | loss 0.93
# | epoch 12 |  iter 241 / 351 | time 35[s] | loss 0.95
# | epoch 12 |  iter 261 / 351 | time 38[s] | loss 0.94
# | epoch 12 |  iter 281 / 351 | time 41[s] | loss 0.91
# | epoch 12 |  iter 301 / 351 | time 44[s] | loss 0.92
# | epoch 12 |  iter 321 / 351 | time 46[s] | loss 0.90
# | epoch 12 |  iter 341 / 351 | time 49[s] | loss 0.91
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1160
# ---
# Q 582+84
# T 666
# X 681
# ---
# Q 8+155
# T 163
# X 161
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 849
# ---
# Q 761+292
# T 1053
# X 1049
# ---
# Q 830+597
# T 1427
# X 1441
# ---
# Q 26+838
# T 864
# X 871
# ---
# Q 143+93
# T 236
# X 229
# ---
# val acc 6.680%
# | epoch 13 |  iter 1 / 351 | time 0[s] | loss 0.90
# | epoch 13 |  iter 21 / 351 | time 3[s] | loss 0.91
# | epoch 13 |  iter 41 / 351 | time 7[s] | loss 0.90
# | epoch 13 |  iter 61 / 351 | time 9[s] | loss 0.92
# | epoch 13 |  iter 81 / 351 | time 12[s] | loss 0.91
# | epoch 13 |  iter 101 / 351 | time 15[s] | loss 0.90
# | epoch 13 |  iter 121 / 351 | time 18[s] | loss 0.92
# | epoch 13 |  iter 141 / 351 | time 21[s] | loss 0.90
# | epoch 13 |  iter 161 / 351 | time 24[s] | loss 0.89
# | epoch 13 |  iter 181 / 351 | time 27[s] | loss 0.90
# | epoch 13 |  iter 201 / 351 | time 30[s] | loss 0.90
# | epoch 13 |  iter 221 / 351 | time 33[s] | loss 0.89
# | epoch 13 |  iter 241 / 351 | time 36[s] | loss 0.91
# | epoch 13 |  iter 261 / 351 | time 39[s] | loss 0.89
# | epoch 13 |  iter 281 / 351 | time 41[s] | loss 0.91
# | epoch 13 |  iter 301 / 351 | time 44[s] | loss 0.93
# | epoch 13 |  iter 321 / 351 | time 47[s] | loss 0.91
# | epoch 13 |  iter 341 / 351 | time 50[s] | loss 0.88
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1131
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 851
# ---
# Q 761+292
# T 1053
# X 1049
# ---
# Q 830+597
# T 1427
# X 1444
# ---
# Q 26+838
# T 864
# X 859
# ---
# Q 143+93
# T 236
# X 237
# ---
# val acc 6.120%
# | epoch 14 |  iter 1 / 351 | time 0[s] | loss 0.92
# | epoch 14 |  iter 21 / 351 | time 3[s] | loss 0.88
# | epoch 14 |  iter 41 / 351 | time 5[s] | loss 0.91
# | epoch 14 |  iter 61 / 351 | time 8[s] | loss 0.91
# | epoch 14 |  iter 81 / 351 | time 11[s] | loss 0.91
# | epoch 14 |  iter 101 / 351 | time 14[s] | loss 0.90
# | epoch 14 |  iter 121 / 351 | time 17[s] | loss 0.88
# | epoch 14 |  iter 141 / 351 | time 20[s] | loss 0.88
# | epoch 14 |  iter 161 / 351 | time 23[s] | loss 0.89
# | epoch 14 |  iter 181 / 351 | time 26[s] | loss 0.88
# | epoch 14 |  iter 201 / 351 | time 29[s] | loss 0.88
# | epoch 14 |  iter 221 / 351 | time 31[s] | loss 0.88
# | epoch 14 |  iter 241 / 351 | time 34[s] | loss 0.89
# | epoch 14 |  iter 261 / 351 | time 37[s] | loss 0.87
# | epoch 14 |  iter 281 / 351 | time 40[s] | loss 0.87
# | epoch 14 |  iter 301 / 351 | time 43[s] | loss 0.87
# | epoch 14 |  iter 321 / 351 | time 46[s] | loss 0.90
# | epoch 14 |  iter 341 / 351 | time 49[s] | loss 0.91
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1128
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 172
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1072
# ---
# Q 830+597
# T 1427
# X 1424
# ---
# Q 26+838
# T 864
# X 875
# ---
# Q 143+93
# T 236
# X 239
# ---
# val acc 5.560%
# | epoch 15 |  iter 1 / 351 | time 0[s] | loss 0.87
# | epoch 15 |  iter 21 / 351 | time 3[s] | loss 0.87
# | epoch 15 |  iter 41 / 351 | time 5[s] | loss 0.87
# | epoch 15 |  iter 61 / 351 | time 8[s] | loss 0.86
# | epoch 15 |  iter 81 / 351 | time 11[s] | loss 0.90
# | epoch 15 |  iter 101 / 351 | time 14[s] | loss 0.89
# | epoch 15 |  iter 121 / 351 | time 17[s] | loss 0.86
# | epoch 15 |  iter 141 / 351 | time 20[s] | loss 0.87
# | epoch 15 |  iter 161 / 351 | time 23[s] | loss 0.89
# | epoch 15 |  iter 181 / 351 | time 26[s] | loss 0.90
# | epoch 15 |  iter 201 / 351 | time 28[s] | loss 0.90
# | epoch 15 |  iter 221 / 351 | time 31[s] | loss 0.85
# | epoch 15 |  iter 241 / 351 | time 34[s] | loss 0.86
# | epoch 15 |  iter 261 / 351 | time 37[s] | loss 0.88
# | epoch 15 |  iter 281 / 351 | time 40[s] | loss 0.87
# | epoch 15 |  iter 301 / 351 | time 43[s] | loss 0.87
# | epoch 15 |  iter 321 / 351 | time 46[s] | loss 0.86
# | epoch 15 |  iter 341 / 351 | time 49[s] | loss 0.90
# Q 77+85
# T 162
# X 164
# ---
# Q 975+164
# T 1139
# X 1162
# ---
# Q 582+84
# T 666
# X 685
# ---
# Q 8+155
# T 163
# X 172
# ---
# Q 367+55
# T 422
# X 428
# ---
# Q 600+257
# T 857
# X 876
# ---
# Q 761+292
# T 1053
# X 1063
# ---
# Q 830+597
# T 1427
# X 1424
# ---
# Q 26+838
# T 864
# X 876
# ---
# Q 143+93
# T 236
# X 242
# ---
# val acc 3.780%
# | epoch 16 |  iter 1 / 351 | time 0[s] | loss 0.91
# | epoch 16 |  iter 21 / 351 | time 3[s] | loss 0.88
# | epoch 16 |  iter 41 / 351 | time 5[s] | loss 0.89
# | epoch 16 |  iter 61 / 351 | time 8[s] | loss 0.88
# | epoch 16 |  iter 81 / 351 | time 11[s] | loss 0.84
# | epoch 16 |  iter 101 / 351 | time 14[s] | loss 0.94
# | epoch 16 |  iter 121 / 351 | time 17[s] | loss 0.85
# | epoch 16 |  iter 141 / 351 | time 20[s] | loss 0.86
# | epoch 16 |  iter 161 / 351 | time 23[s] | loss 0.85
# | epoch 16 |  iter 181 / 351 | time 26[s] | loss 0.87
# | epoch 16 |  iter 201 / 351 | time 29[s] | loss 0.86
# | epoch 16 |  iter 221 / 351 | time 32[s] | loss 0.86
# | epoch 16 |  iter 241 / 351 | time 34[s] | loss 0.84
# | epoch 16 |  iter 261 / 351 | time 37[s] | loss 0.84
# | epoch 16 |  iter 281 / 351 | time 40[s] | loss 0.88
# | epoch 16 |  iter 301 / 351 | time 44[s] | loss 0.88
# | epoch 16 |  iter 321 / 351 | time 46[s] | loss 0.87
# | epoch 16 |  iter 341 / 351 | time 49[s] | loss 0.88
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 662
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 412
# ---
# Q 600+257
# T 857
# X 849
# ---
# Q 761+292
# T 1053
# X 1049
# ---
# Q 830+597
# T 1427
# X 1414
# ---
# Q 26+838
# T 864
# X 857
# ---
# Q 143+93
# T 236
# X 239
# ---
# val acc 6.880%
# | epoch 17 |  iter 1 / 351 | time 0[s] | loss 0.86
# | epoch 17 |  iter 21 / 351 | time 3[s] | loss 0.87
# | epoch 17 |  iter 41 / 351 | time 5[s] | loss 0.87
# | epoch 17 |  iter 61 / 351 | time 8[s] | loss 0.86
# | epoch 17 |  iter 81 / 351 | time 11[s] | loss 0.87
# | epoch 17 |  iter 101 / 351 | time 14[s] | loss 0.86
# | epoch 17 |  iter 121 / 351 | time 17[s] | loss 0.87
# | epoch 17 |  iter 141 / 351 | time 20[s] | loss 0.86
# | epoch 17 |  iter 161 / 351 | time 23[s] | loss 0.86
# | epoch 17 |  iter 181 / 351 | time 26[s] | loss 0.87
# | epoch 17 |  iter 201 / 351 | time 29[s] | loss 0.87
# | epoch 17 |  iter 221 / 351 | time 31[s] | loss 0.85
# | epoch 17 |  iter 241 / 351 | time 34[s] | loss 0.84
# | epoch 17 |  iter 261 / 351 | time 37[s] | loss 0.83
# | epoch 17 |  iter 281 / 351 | time 40[s] | loss 0.87
# | epoch 17 |  iter 301 / 351 | time 43[s] | loss 0.83
# | epoch 17 |  iter 321 / 351 | time 46[s] | loss 0.86
# | epoch 17 |  iter 341 / 351 | time 49[s] | loss 0.85
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1127
# ---
# Q 582+84
# T 666
# X 672
# ---
# Q 8+155
# T 163
# X 157
# ---
# Q 367+55
# T 422
# X 417
# ---
# Q 600+257
# T 857
# X 866
# ---
# Q 761+292
# T 1053
# X 1049
# ---
# Q 830+597
# T 1427
# X 1424
# ---
# Q 26+838
# T 864
# X 876
# ---
# Q 143+93
# T 236
# X 239
# ---
# val acc 7.940%
# | epoch 18 |  iter 1 / 351 | time 0[s] | loss 0.85
# | epoch 18 |  iter 21 / 351 | time 3[s] | loss 0.84
# | epoch 18 |  iter 41 / 351 | time 5[s] | loss 0.83
# | epoch 18 |  iter 61 / 351 | time 8[s] | loss 0.83
# | epoch 18 |  iter 81 / 351 | time 11[s] | loss 0.83
# | epoch 18 |  iter 101 / 351 | time 14[s] | loss 0.86
# | epoch 18 |  iter 121 / 351 | time 17[s] | loss 0.84
# | epoch 18 |  iter 141 / 351 | time 20[s] | loss 0.83
# | epoch 18 |  iter 161 / 351 | time 23[s] | loss 0.84
# | epoch 18 |  iter 181 / 351 | time 26[s] | loss 0.82
# | epoch 18 |  iter 201 / 351 | time 28[s] | loss 0.85
# | epoch 18 |  iter 221 / 351 | time 31[s] | loss 0.83
# | epoch 18 |  iter 241 / 351 | time 34[s] | loss 0.85
# | epoch 18 |  iter 261 / 351 | time 37[s] | loss 0.83
# | epoch 18 |  iter 281 / 351 | time 40[s] | loss 0.82
# | epoch 18 |  iter 301 / 351 | time 43[s] | loss 0.85
# | epoch 18 |  iter 321 / 351 | time 46[s] | loss 0.85
# | epoch 18 |  iter 341 / 351 | time 49[s] | loss 0.84
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1118
# ---
# Q 582+84
# T 666
# X 658
# ---
# Q 8+155
# T 163
# X 158
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 849
# ---
# Q 761+292
# T 1053
# X 1049
# ---
# Q 830+597
# T 1427
# X 1410
# ---
# Q 26+838
# T 864
# X 867
# ---
# Q 143+93
# T 236
# X 239
# ---
# val acc 9.340%
# | epoch 19 |  iter 1 / 351 | time 0[s] | loss 0.85
# | epoch 19 |  iter 21 / 351 | time 3[s] | loss 0.84
# | epoch 19 |  iter 41 / 351 | time 5[s] | loss 0.85
# | epoch 19 |  iter 61 / 351 | time 8[s] | loss 0.85
# | epoch 19 |  iter 81 / 351 | time 11[s] | loss 0.84
# | epoch 19 |  iter 101 / 351 | time 14[s] | loss 0.84
# | epoch 19 |  iter 121 / 351 | time 17[s] | loss 0.85
# | epoch 19 |  iter 141 / 351 | time 20[s] | loss 0.84
# | epoch 19 |  iter 161 / 351 | time 23[s] | loss 0.83
# | epoch 19 |  iter 181 / 351 | time 26[s] | loss 0.86
# | epoch 19 |  iter 201 / 351 | time 28[s] | loss 0.84
# | epoch 19 |  iter 221 / 351 | time 31[s] | loss 0.82
# | epoch 19 |  iter 241 / 351 | time 34[s] | loss 0.84
# | epoch 19 |  iter 261 / 351 | time 37[s] | loss 0.83
# | epoch 19 |  iter 281 / 351 | time 40[s] | loss 0.83
# | epoch 19 |  iter 301 / 351 | time 43[s] | loss 0.87
# | epoch 19 |  iter 321 / 351 | time 46[s] | loss 0.84
# | epoch 19 |  iter 341 / 351 | time 49[s] | loss 0.84
# Q 77+85
# T 162
# X 159
# ---
# Q 975+164
# T 1139
# X 1162
# ---
# Q 582+84
# T 666
# X 672
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# X 1049
# ---
# Q 830+597
# T 1427
# X 1441
# ---
# Q 26+838
# T 864
# X 867
# ---
# Q 143+93
# T 236
# X 242
# ---
# val acc 9.600%
# | epoch 20 |  iter 1 / 351 | time 0[s] | loss 0.79
# | epoch 20 |  iter 21 / 351 | time 3[s] | loss 0.83
# | epoch 20 |  iter 41 / 351 | time 5[s] | loss 0.83
# | epoch 20 |  iter 61 / 351 | time 8[s] | loss 0.81
# | epoch 20 |  iter 81 / 351 | time 11[s] | loss 0.82
# | epoch 20 |  iter 101 / 351 | time 14[s] | loss 0.83
# | epoch 20 |  iter 121 / 351 | time 17[s] | loss 0.85
# | epoch 20 |  iter 141 / 351 | time 20[s] | loss 0.85
# | epoch 20 |  iter 161 / 351 | time 23[s] | loss 0.84
# | epoch 20 |  iter 181 / 351 | time 26[s] | loss 0.82
# | epoch 20 |  iter 201 / 351 | time 29[s] | loss 0.82
# | epoch 20 |  iter 221 / 351 | time 32[s] | loss 0.83
# | epoch 20 |  iter 241 / 351 | time 34[s] | loss 0.85
# | epoch 20 |  iter 261 / 351 | time 37[s] | loss 0.82
# | epoch 20 |  iter 281 / 351 | time 40[s] | loss 0.79
# | epoch 20 |  iter 301 / 351 | time 43[s] | loss 0.80
# | epoch 20 |  iter 321 / 351 | time 46[s] | loss 0.84
# | epoch 20 |  iter 341 / 351 | time 49[s] | loss 0.80
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1131
# ---
# Q 582+84
# T 666
# X 662
# ---
# Q 8+155
# T 163
# X 167
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 849
# ---
# Q 761+292
# T 1053
# X 1049
# ---
# Q 830+597
# T 1427
# X 1424
# ---
# Q 26+838
# T 864
# X 871
# ---
# Q 143+93
# T 236
# X 239
# ---
# val acc 9.360%
# | epoch 21 |  iter 1 / 351 | time 0[s] | loss 0.80
# | epoch 21 |  iter 21 / 351 | time 3[s] | loss 0.80
# | epoch 21 |  iter 41 / 351 | time 5[s] | loss 0.80
# | epoch 21 |  iter 61 / 351 | time 8[s] | loss 0.83
# | epoch 21 |  iter 81 / 351 | time 11[s] | loss 0.83
# | epoch 21 |  iter 101 / 351 | time 14[s] | loss 0.82
# | epoch 21 |  iter 121 / 351 | time 17[s] | loss 0.79
# | epoch 21 |  iter 141 / 351 | time 20[s] | loss 0.80
# | epoch 21 |  iter 161 / 351 | time 23[s] | loss 0.82
# | epoch 21 |  iter 181 / 351 | time 26[s] | loss 0.79
# | epoch 21 |  iter 201 / 351 | time 28[s] | loss 0.82
# | epoch 21 |  iter 221 / 351 | time 31[s] | loss 0.83
# | epoch 21 |  iter 241 / 351 | time 34[s] | loss 0.79
# | epoch 21 |  iter 261 / 351 | time 37[s] | loss 0.79
# | epoch 21 |  iter 281 / 351 | time 40[s] | loss 0.82
# | epoch 21 |  iter 301 / 351 | time 43[s] | loss 0.80
# | epoch 21 |  iter 321 / 351 | time 46[s] | loss 0.83
# | epoch 21 |  iter 341 / 351 | time 49[s] | loss 0.84
# Q 77+85
# T 162
# X 164
# ---
# Q 975+164
# T 1139
# X 1127
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# X 164
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1049
# ---
# Q 830+597
# T 1427
# X 1424
# ---
# Q 26+838
# T 864
# X 862
# ---
# Q 143+93
# T 236
# X 237
# ---
# val acc 11.620%
# | epoch 22 |  iter 1 / 351 | time 0[s] | loss 0.80
# | epoch 22 |  iter 21 / 351 | time 3[s] | loss 0.78
# | epoch 22 |  iter 41 / 351 | time 5[s] | loss 0.81
# | epoch 22 |  iter 61 / 351 | time 8[s] | loss 0.83
# | epoch 22 |  iter 81 / 351 | time 11[s] | loss 0.79
# | epoch 22 |  iter 101 / 351 | time 14[s] | loss 0.80
# | epoch 22 |  iter 121 / 351 | time 17[s] | loss 0.83
# | epoch 22 |  iter 141 / 351 | time 20[s] | loss 0.80
# | epoch 22 |  iter 161 / 351 | time 23[s] | loss 0.81
# | epoch 22 |  iter 181 / 351 | time 26[s] | loss 0.83
# | epoch 22 |  iter 201 / 351 | time 29[s] | loss 0.77
# | epoch 22 |  iter 221 / 351 | time 31[s] | loss 0.82
# | epoch 22 |  iter 241 / 351 | time 34[s] | loss 0.80
# | epoch 22 |  iter 261 / 351 | time 37[s] | loss 0.80
# | epoch 22 |  iter 281 / 351 | time 40[s] | loss 0.79
# | epoch 22 |  iter 301 / 351 | time 43[s] | loss 0.81
# | epoch 22 |  iter 321 / 351 | time 46[s] | loss 0.80
# | epoch 22 |  iter 341 / 351 | time 49[s] | loss 0.80
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1150
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# X 157
# ---
# Q 367+55
# T 422
# X 427
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1063
# ---
# Q 830+597
# T 1427
# X 1424
# ---
# Q 26+838
# T 864
# X 867
# ---
# Q 143+93
# T 236
# X 237
# ---
# val acc 8.760%
# | epoch 23 |  iter 1 / 351 | time 0[s] | loss 0.77
# | epoch 23 |  iter 21 / 351 | time 3[s] | loss 0.79
# | epoch 23 |  iter 41 / 351 | time 5[s] | loss 0.78
# | epoch 23 |  iter 61 / 351 | time 8[s] | loss 0.78
# | epoch 23 |  iter 81 / 351 | time 11[s] | loss 0.78
# | epoch 23 |  iter 101 / 351 | time 14[s] | loss 0.80
# | epoch 23 |  iter 121 / 351 | time 17[s] | loss 0.78
# | epoch 23 |  iter 141 / 351 | time 20[s] | loss 0.80
# | epoch 23 |  iter 161 / 351 | time 23[s] | loss 0.79
# | epoch 23 |  iter 181 / 351 | time 26[s] | loss 0.78
# | epoch 23 |  iter 201 / 351 | time 28[s] | loss 0.78
# | epoch 23 |  iter 221 / 351 | time 31[s] | loss 0.83
# | epoch 23 |  iter 241 / 351 | time 34[s] | loss 0.81
# | epoch 23 |  iter 261 / 351 | time 37[s] | loss 0.79
# | epoch 23 |  iter 281 / 351 | time 40[s] | loss 0.84
# | epoch 23 |  iter 301 / 351 | time 43[s] | loss 0.80
# | epoch 23 |  iter 321 / 351 | time 46[s] | loss 0.77
# | epoch 23 |  iter 341 / 351 | time 49[s] | loss 0.76
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1130
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 160
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 860
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1415
# ---
# Q 26+838
# T 864
# X 861
# ---
# Q 143+93
# T 236
# X 239
# ---
# val acc 10.600%
# | epoch 24 |  iter 1 / 351 | time 0[s] | loss 0.74
# | epoch 24 |  iter 21 / 351 | time 3[s] | loss 0.77
# | epoch 24 |  iter 41 / 351 | time 5[s] | loss 0.78
# | epoch 24 |  iter 61 / 351 | time 8[s] | loss 0.77
# | epoch 24 |  iter 81 / 351 | time 11[s] | loss 0.77
# | epoch 24 |  iter 101 / 351 | time 14[s] | loss 0.77
# | epoch 24 |  iter 121 / 351 | time 17[s] | loss 0.76
# | epoch 24 |  iter 141 / 351 | time 20[s] | loss 0.78
# | epoch 24 |  iter 161 / 351 | time 23[s] | loss 0.77
# | epoch 24 |  iter 181 / 351 | time 26[s] | loss 0.78
# | epoch 24 |  iter 201 / 351 | time 29[s] | loss 0.77
# | epoch 24 |  iter 221 / 351 | time 31[s] | loss 0.81
# | epoch 24 |  iter 241 / 351 | time 34[s] | loss 0.80
# | epoch 24 |  iter 261 / 351 | time 37[s] | loss 0.81
# | epoch 24 |  iter 281 / 351 | time 40[s] | loss 0.78
# | epoch 24 |  iter 301 / 351 | time 43[s] | loss 0.79
# | epoch 24 |  iter 321 / 351 | time 46[s] | loss 0.79
# | epoch 24 |  iter 341 / 351 | time 49[s] | loss 0.83
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1138
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 167
# ---
# Q 367+55
# T 422
# X 425
# ---
# Q 600+257
# T 857
# X 851
# ---
# Q 761+292
# T 1053
# X 1055
# ---
# Q 830+597
# T 1427
# X 1441
# ---
# Q 26+838
# T 864
# X 857
# ---
# Q 143+93
# T 236
# X 235
# ---
# val acc 11.140%
# | epoch 25 |  iter 1 / 351 | time 0[s] | loss 0.74
# | epoch 25 |  iter 21 / 351 | time 3[s] | loss 0.78
# | epoch 25 |  iter 41 / 351 | time 5[s] | loss 0.77
# | epoch 25 |  iter 61 / 351 | time 8[s] | loss 0.77
# | epoch 25 |  iter 81 / 351 | time 11[s] | loss 0.75
# | epoch 25 |  iter 101 / 351 | time 14[s] | loss 0.76
# | epoch 25 |  iter 121 / 351 | time 17[s] | loss 0.78
# | epoch 25 |  iter 141 / 351 | time 20[s] | loss 0.80
# | epoch 25 |  iter 161 / 351 | time 23[s] | loss 0.75
# | epoch 25 |  iter 181 / 351 | time 26[s] | loss 0.76
# | epoch 25 |  iter 201 / 351 | time 29[s] | loss 0.75
# | epoch 25 |  iter 221 / 351 | time 31[s] | loss 0.77
# | epoch 25 |  iter 241 / 351 | time 34[s] | loss 0.80
# | epoch 25 |  iter 261 / 351 | time 37[s] | loss 0.81
# | epoch 25 |  iter 281 / 351 | time 40[s] | loss 0.76
# | epoch 25 |  iter 301 / 351 | time 43[s] | loss 0.75
# | epoch 25 |  iter 321 / 351 | time 46[s] | loss 0.77
# | epoch 25 |  iter 341 / 351 | time 49[s] | loss 0.76
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1146
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# X 426
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1049
# ---
# Q 830+597
# T 1427
# X 1441
# ---
# Q 26+838
# T 864
# X 862
# ---
# Q 143+93
# T 236
# X 239
# ---
# val acc 10.160%

# %% [markdown]
# ## 7.4 seq2seqの改良
#
# ### 7.4.1 入力データの反転（Reverse）
#
# 入力データを反転させると学習の進みが良くなる。
# 理論的なことは分かってないが（わかってないんかーい）、直感的には勾配の伝播がスムーズになるからだと考えられる。

# %%
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
#from seq2seq import Seq2seq
#from peeky_seq2seq import PeekySeq2seq


# データセットの読み込み
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

# Reverse input? =================================================
is_reverse = True # ここを変えた
if is_reverse:
    x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]
# ================================================================

# ハイパーパラメータの設定
vocab_size = len(char_to_id)
wordvec_size = 16
hideen_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

# Normal or Peeky? ==============================================
model = Seq2seq(vocab_size, wordvec_size, hideen_size)
# model = PeekySeq2seq(vocab_size, wordvec_size, hideen_size)
# ================================================================
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1,
                batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct,
                                    id_to_char, verbose, is_reverse)

    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('val acc %.3f%%' % (acc * 100))
# Out:
# | epoch 1 |  iter 1 / 351 | time 0[s] | loss 2.56
# | epoch 1 |  iter 21 / 351 | time 2[s] | loss 2.52
# | epoch 1 |  iter 41 / 351 | time 5[s] | loss 2.17
# | epoch 1 |  iter 61 / 351 | time 8[s] | loss 1.96
# | epoch 1 |  iter 81 / 351 | time 11[s] | loss 1.91
# | epoch 1 |  iter 101 / 351 | time 14[s] | loss 1.87
# | epoch 1 |  iter 121 / 351 | time 16[s] | loss 1.86
# | epoch 1 |  iter 141 / 351 | time 19[s] | loss 1.84
# | epoch 1 |  iter 161 / 351 | time 22[s] | loss 1.80
# | epoch 1 |  iter 181 / 351 | time 25[s] | loss 1.78
# | epoch 1 |  iter 201 / 351 | time 28[s] | loss 1.77
# | epoch 1 |  iter 221 / 351 | time 31[s] | loss 1.77
# | epoch 1 |  iter 241 / 351 | time 33[s] | loss 1.76
# | epoch 1 |  iter 261 / 351 | time 36[s] | loss 1.75
# | epoch 1 |  iter 281 / 351 | time 39[s] | loss 1.74
# | epoch 1 |  iter 301 / 351 | time 42[s] | loss 1.74
# | epoch 1 |  iter 321 / 351 | time 45[s] | loss 1.74
# | epoch 1 |  iter 341 / 351 | time 48[s] | loss 1.73
# Q 77+85
# T 162
# X 100
# ---
# Q 975+164
# T 1139
# X 1000
# ---
# Q 582+84
# T 666
# X 1001
# ---
# Q 8+155
# T 163
# X 100
# ---
# Q 367+55
# T 422
# X 1001
# ---
# Q 600+257
# T 857
# X 1000
# ---
# Q 761+292
# T 1053
# X 1000
# ---
# Q 830+597
# T 1427
# X 1000
# ---
# Q 26+838
# T 864
# X 1001
# ---
# Q 143+93
# T 236
# X 703
# ---
# val acc 0.120%
# | epoch 2 |  iter 1 / 351 | time 0[s] | loss 1.73
# | epoch 2 |  iter 21 / 351 | time 2[s] | loss 1.72
# | epoch 2 |  iter 41 / 351 | time 5[s] | loss 1.72
# | epoch 2 |  iter 61 / 351 | time 8[s] | loss 1.72
# | epoch 2 |  iter 81 / 351 | time 11[s] | loss 1.70
# | epoch 2 |  iter 101 / 351 | time 14[s] | loss 1.70
# | epoch 2 |  iter 121 / 351 | time 17[s] | loss 1.69
# | epoch 2 |  iter 141 / 351 | time 20[s] | loss 1.68
# | epoch 2 |  iter 161 / 351 | time 22[s] | loss 1.67
# | epoch 2 |  iter 181 / 351 | time 25[s] | loss 1.66
# | epoch 2 |  iter 201 / 351 | time 28[s] | loss 1.66
# | epoch 2 |  iter 221 / 351 | time 31[s] | loss 1.65
# | epoch 2 |  iter 241 / 351 | time 34[s] | loss 1.63
# | epoch 2 |  iter 261 / 351 | time 37[s] | loss 1.62
# | epoch 2 |  iter 281 / 351 | time 39[s] | loss 1.61
# | epoch 2 |  iter 301 / 351 | time 42[s] | loss 1.60
# | epoch 2 |  iter 321 / 351 | time 45[s] | loss 1.58
# | epoch 2 |  iter 341 / 351 | time 48[s] | loss 1.56
# Q 77+85
# T 162
# X 100
# ---
# Q 975+164
# T 1139
# X 1000
# ---
# Q 582+84
# T 666
# X 690
# ---
# Q 8+155
# T 163
# X 1000
# ---
# Q 367+55
# T 422
# X 470
# ---
# Q 600+257
# T 857
# X 700
# ---
# Q 761+292
# T 1053
# X 1000
# ---
# Q 830+597
# T 1427
# X 1444
# ---
# Q 26+838
# T 864
# X 700
# ---
# Q 143+93
# T 236
# X 370
# ---
# val acc 0.400%
# | epoch 3 |  iter 1 / 351 | time 0[s] | loss 1.52
# | epoch 3 |  iter 21 / 351 | time 2[s] | loss 1.53
# | epoch 3 |  iter 41 / 351 | time 5[s] | loss 1.51
# | epoch 3 |  iter 61 / 351 | time 8[s] | loss 1.49
# | epoch 3 |  iter 81 / 351 | time 11[s] | loss 1.47
# | epoch 3 |  iter 101 / 351 | time 14[s] | loss 1.45
# | epoch 3 |  iter 121 / 351 | time 16[s] | loss 1.44
# | epoch 3 |  iter 141 / 351 | time 19[s] | loss 1.42
# | epoch 3 |  iter 161 / 351 | time 22[s] | loss 1.40
# | epoch 3 |  iter 181 / 351 | time 25[s] | loss 1.38
# | epoch 3 |  iter 201 / 351 | time 28[s] | loss 1.37
# | epoch 3 |  iter 221 / 351 | time 30[s] | loss 1.35
# | epoch 3 |  iter 241 / 351 | time 33[s] | loss 1.33
# | epoch 3 |  iter 261 / 351 | time 36[s] | loss 1.32
# | epoch 3 |  iter 281 / 351 | time 39[s] | loss 1.30
# | epoch 3 |  iter 301 / 351 | time 42[s] | loss 1.29
# | epoch 3 |  iter 321 / 351 | time 44[s] | loss 1.28
# | epoch 3 |  iter 341 / 351 | time 47[s] | loss 1.27
# Q 77+85
# T 162
# X 158
# ---
# Q 975+164
# T 1139
# X 1148
# ---
# Q 582+84
# T 666
# X 662
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 382
# ---
# Q 600+257
# T 857
# X 818
# ---
# Q 761+292
# T 1053
# X 1008
# ---
# Q 830+597
# T 1427
# X 1434
# ---
# Q 26+838
# T 864
# X 838
# ---
# Q 143+93
# T 236
# X 202
# ---
# val acc 1.940%
# | epoch 4 |  iter 1 / 351 | time 0[s] | loss 1.26
# | epoch 4 |  iter 21 / 351 | time 2[s] | loss 1.25
# | epoch 4 |  iter 41 / 351 | time 5[s] | loss 1.23
# | epoch 4 |  iter 61 / 351 | time 8[s] | loss 1.22
# | epoch 4 |  iter 81 / 351 | time 11[s] | loss 1.20
# | epoch 4 |  iter 101 / 351 | time 14[s] | loss 1.19
# | epoch 4 |  iter 121 / 351 | time 16[s] | loss 1.18
# | epoch 4 |  iter 141 / 351 | time 19[s] | loss 1.17
# | epoch 4 |  iter 161 / 351 | time 22[s] | loss 1.15
# | epoch 4 |  iter 181 / 351 | time 25[s] | loss 1.13
# | epoch 4 |  iter 201 / 351 | time 28[s] | loss 1.12
# | epoch 4 |  iter 221 / 351 | time 31[s] | loss 1.11
# | epoch 4 |  iter 241 / 351 | time 33[s] | loss 1.09
# | epoch 4 |  iter 261 / 351 | time 36[s] | loss 1.08
# | epoch 4 |  iter 281 / 351 | time 39[s] | loss 1.07
# | epoch 4 |  iter 301 / 351 | time 42[s] | loss 1.07
# | epoch 4 |  iter 321 / 351 | time 45[s] | loss 1.05
# | epoch 4 |  iter 341 / 351 | time 48[s] | loss 1.03
# Q 77+85
# T 162
# X 166
# ---
# Q 975+164
# T 1139
# X 1196
# ---
# Q 582+84
# T 666
# X 668
# ---
# Q 8+155
# T 163
# X 166
# ---
# Q 367+55
# T 422
# X 419
# ---
# Q 600+257
# T 857
# X 896
# ---
# Q 761+292
# T 1053
# X 1010
# ---
# Q 830+597
# T 1427
# X 1496
# ---
# Q 26+838
# T 864
# X 868
# ---
# Q 143+93
# T 236
# X 239
# ---
# val acc 5.780%
# | epoch 5 |  iter 1 / 351 | time 0[s] | loss 1.01
# | epoch 5 |  iter 21 / 351 | time 2[s] | loss 1.01
# | epoch 5 |  iter 41 / 351 | time 5[s] | loss 1.00
# | epoch 5 |  iter 61 / 351 | time 8[s] | loss 0.99
# | epoch 5 |  iter 81 / 351 | time 11[s] | loss 0.97
# | epoch 5 |  iter 101 / 351 | time 14[s] | loss 0.95
# | epoch 5 |  iter 121 / 351 | time 17[s] | loss 0.95
# | epoch 5 |  iter 141 / 351 | time 19[s] | loss 0.94
# | epoch 5 |  iter 161 / 351 | time 22[s] | loss 0.93
# | epoch 5 |  iter 181 / 351 | time 25[s] | loss 0.93
# | epoch 5 |  iter 201 / 351 | time 28[s] | loss 0.91
# | epoch 5 |  iter 221 / 351 | time 31[s] | loss 0.89
# | epoch 5 |  iter 241 / 351 | time 34[s] | loss 0.89
# | epoch 5 |  iter 261 / 351 | time 36[s] | loss 0.88
# | epoch 5 |  iter 281 / 351 | time 39[s] | loss 0.87
# | epoch 5 |  iter 301 / 351 | time 42[s] | loss 0.86
# | epoch 5 |  iter 321 / 351 | time 45[s] | loss 0.85
# | epoch 5 |  iter 341 / 351 | time 48[s] | loss 0.84
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1192
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 166
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# X 860
# ---
# Q 761+292
# T 1053
# X 1066
# ---
# Q 830+597
# T 1427
# X 1414
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# X 232
# ---
# val acc 12.460%
# | epoch 6 |  iter 1 / 351 | time 0[s] | loss 0.86
# | epoch 6 |  iter 21 / 351 | time 2[s] | loss 0.82
# | epoch 6 |  iter 41 / 351 | time 5[s] | loss 0.82
# | epoch 6 |  iter 61 / 351 | time 8[s] | loss 0.81
# | epoch 6 |  iter 81 / 351 | time 11[s] | loss 0.80
# | epoch 6 |  iter 101 / 351 | time 14[s] | loss 0.80
# | epoch 6 |  iter 121 / 351 | time 17[s] | loss 0.79
# | epoch 6 |  iter 141 / 351 | time 19[s] | loss 0.78
# | epoch 6 |  iter 161 / 351 | time 22[s] | loss 0.77
# | epoch 6 |  iter 181 / 351 | time 25[s] | loss 0.77
# | epoch 6 |  iter 201 / 351 | time 28[s] | loss 0.78
# | epoch 6 |  iter 221 / 351 | time 31[s] | loss 0.76
# | epoch 6 |  iter 241 / 351 | time 34[s] | loss 0.75
# | epoch 6 |  iter 261 / 351 | time 36[s] | loss 0.74
# | epoch 6 |  iter 281 / 351 | time 39[s] | loss 0.73
# | epoch 6 |  iter 301 / 351 | time 42[s] | loss 0.73
# | epoch 6 |  iter 321 / 351 | time 45[s] | loss 0.72
# | epoch 6 |  iter 341 / 351 | time 48[s] | loss 0.72
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1141
# ---
# Q 582+84
# T 666
# X 661
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 851
# ---
# Q 761+292
# T 1053
# X 1061
# ---
# Q 830+597
# T 1427
# X 1391
# ---
# Q 26+838
# T 864
# X 866
# ---
# Q 143+93
# T 236
# X 234
# ---
# val acc 14.260%
# | epoch 7 |  iter 1 / 351 | time 0[s] | loss 0.71
# | epoch 7 |  iter 21 / 351 | time 3[s] | loss 0.71
# | epoch 7 |  iter 41 / 351 | time 5[s] | loss 0.70
# | epoch 7 |  iter 61 / 351 | time 8[s] | loss 0.70
# | epoch 7 |  iter 81 / 351 | time 11[s] | loss 0.68
# | epoch 7 |  iter 101 / 351 | time 14[s] | loss 0.68
# | epoch 7 |  iter 121 / 351 | time 17[s] | loss 0.67
# | epoch 7 |  iter 141 / 351 | time 19[s] | loss 0.67
# | epoch 7 |  iter 161 / 351 | time 22[s] | loss 0.67
# | epoch 7 |  iter 181 / 351 | time 25[s] | loss 0.66
# | epoch 7 |  iter 201 / 351 | time 28[s] | loss 0.66
# | epoch 7 |  iter 221 / 351 | time 31[s] | loss 0.66
# | epoch 7 |  iter 241 / 351 | time 34[s] | loss 0.64
# | epoch 7 |  iter 261 / 351 | time 36[s] | loss 0.65
# | epoch 7 |  iter 281 / 351 | time 39[s] | loss 0.64
# | epoch 7 |  iter 301 / 351 | time 42[s] | loss 0.63
# | epoch 7 |  iter 321 / 351 | time 45[s] | loss 0.63
# | epoch 7 |  iter 341 / 351 | time 48[s] | loss 0.62
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1142
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1144
# ---
# Q 830+597
# T 1427
# X 1431
# ---
# Q 26+838
# T 864
# X 866
# ---
# Q 143+93
# T 236
# X 239
# ---
# val acc 17.500%
# | epoch 8 |  iter 1 / 351 | time 0[s] | loss 0.66
# | epoch 8 |  iter 21 / 351 | time 2[s] | loss 0.61
# | epoch 8 |  iter 41 / 351 | time 5[s] | loss 0.62
# | epoch 8 |  iter 61 / 351 | time 8[s] | loss 0.61
# | epoch 8 |  iter 81 / 351 | time 11[s] | loss 0.61
# | epoch 8 |  iter 101 / 351 | time 14[s] | loss 0.61
# | epoch 8 |  iter 121 / 351 | time 17[s] | loss 0.60
# | epoch 8 |  iter 141 / 351 | time 19[s] | loss 0.60
# | epoch 8 |  iter 161 / 351 | time 22[s] | loss 0.59
# | epoch 8 |  iter 181 / 351 | time 25[s] | loss 0.58
# | epoch 8 |  iter 201 / 351 | time 28[s] | loss 0.59
# | epoch 8 |  iter 221 / 351 | time 31[s] | loss 0.60
# | epoch 8 |  iter 241 / 351 | time 34[s] | loss 0.59
# | epoch 8 |  iter 261 / 351 | time 36[s] | loss 0.58
# | epoch 8 |  iter 281 / 351 | time 39[s] | loss 0.59
# | epoch 8 |  iter 301 / 351 | time 42[s] | loss 0.58
# | epoch 8 |  iter 321 / 351 | time 45[s] | loss 0.57
# | epoch 8 |  iter 341 / 351 | time 48[s] | loss 0.57
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1134
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# X 759
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1431
# ---
# Q 26+838
# T 864
# X 866
# ---
# Q 143+93
# T 236
# X 238
# ---
# val acc 23.080%
# | epoch 9 |  iter 1 / 351 | time 0[s] | loss 0.55
# | epoch 9 |  iter 21 / 351 | time 2[s] | loss 0.56
# | epoch 9 |  iter 41 / 351 | time 5[s] | loss 0.56
# | epoch 9 |  iter 61 / 351 | time 8[s] | loss 0.55
# | epoch 9 |  iter 81 / 351 | time 11[s] | loss 0.54
# | epoch 9 |  iter 101 / 351 | time 14[s] | loss 0.55
# | epoch 9 |  iter 121 / 351 | time 17[s] | loss 0.55
# | epoch 9 |  iter 141 / 351 | time 19[s] | loss 0.54
# | epoch 9 |  iter 161 / 351 | time 22[s] | loss 0.55
# | epoch 9 |  iter 181 / 351 | time 25[s] | loss 0.53
# | epoch 9 |  iter 201 / 351 | time 28[s] | loss 0.54
# | epoch 9 |  iter 221 / 351 | time 31[s] | loss 0.54
# | epoch 9 |  iter 241 / 351 | time 34[s] | loss 0.53
# | epoch 9 |  iter 261 / 351 | time 37[s] | loss 0.53
# | epoch 9 |  iter 281 / 351 | time 40[s] | loss 0.54
# | epoch 9 |  iter 301 / 351 | time 42[s] | loss 0.54
# | epoch 9 |  iter 321 / 351 | time 45[s] | loss 0.53
# | epoch 9 |  iter 341 / 351 | time 48[s] | loss 0.53
# Q 77+85
# T 162
# X 158
# ---
# Q 975+164
# T 1139
# X 1142
# ---
# Q 582+84
# T 666
# X 664
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 854
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1428
# ---
# Q 26+838
# T 864
# X 862
# ---
# Q 143+93
# T 236
# X 238
# ---
# val acc 26.520%
# | epoch 10 |  iter 1 / 351 | time 0[s] | loss 0.50
# | epoch 10 |  iter 21 / 351 | time 3[s] | loss 0.51
# | epoch 10 |  iter 41 / 351 | time 5[s] | loss 0.52
# | epoch 10 |  iter 61 / 351 | time 8[s] | loss 0.55
# | epoch 10 |  iter 81 / 351 | time 11[s] | loss 0.52
# | epoch 10 |  iter 101 / 351 | time 14[s] | loss 0.51
# | epoch 10 |  iter 121 / 351 | time 17[s] | loss 0.50
# | epoch 10 |  iter 141 / 351 | time 20[s] | loss 0.51
# | epoch 10 |  iter 161 / 351 | time 22[s] | loss 0.52
# | epoch 10 |  iter 181 / 351 | time 25[s] | loss 0.53
# | epoch 10 |  iter 201 / 351 | time 28[s] | loss 0.50
# | epoch 10 |  iter 221 / 351 | time 31[s] | loss 0.50
# | epoch 10 |  iter 241 / 351 | time 34[s] | loss 0.50
# | epoch 10 |  iter 261 / 351 | time 37[s] | loss 0.50
# | epoch 10 |  iter 281 / 351 | time 40[s] | loss 0.49
# | epoch 10 |  iter 301 / 351 | time 42[s] | loss 0.48
# | epoch 10 |  iter 321 / 351 | time 45[s] | loss 0.48
# | epoch 10 |  iter 341 / 351 | time 48[s] | loss 0.48
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 664
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1054
# ---
# Q 830+597
# T 1427
# X 1431
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 235
# ---
# val acc 29.820%
# | epoch 11 |  iter 1 / 351 | time 0[s] | loss 0.47
# | epoch 11 |  iter 21 / 351 | time 3[s] | loss 0.48
# | epoch 11 |  iter 41 / 351 | time 5[s] | loss 0.48
# | epoch 11 |  iter 61 / 351 | time 8[s] | loss 0.48
# | epoch 11 |  iter 81 / 351 | time 11[s] | loss 0.47
# | epoch 11 |  iter 101 / 351 | time 14[s] | loss 0.47
# | epoch 11 |  iter 121 / 351 | time 17[s] | loss 0.47
# | epoch 11 |  iter 141 / 351 | time 19[s] | loss 0.47
# | epoch 11 |  iter 161 / 351 | time 22[s] | loss 0.48
# | epoch 11 |  iter 181 / 351 | time 25[s] | loss 0.48
# | epoch 11 |  iter 201 / 351 | time 28[s] | loss 0.47
# | epoch 11 |  iter 221 / 351 | time 31[s] | loss 0.47
# | epoch 11 |  iter 241 / 351 | time 34[s] | loss 0.46
# | epoch 11 |  iter 261 / 351 | time 36[s] | loss 0.46
# | epoch 11 |  iter 281 / 351 | time 39[s] | loss 0.46
# | epoch 11 |  iter 301 / 351 | time 42[s] | loss 0.48
# | epoch 11 |  iter 321 / 351 | time 45[s] | loss 0.45
# | epoch 11 |  iter 341 / 351 | time 48[s] | loss 0.45
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1140
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1426
# ---
# Q 26+838
# T 864
# X 866
# ---
# Q 143+93
# T 236
# X 238
# ---
# val acc 28.460%
# | epoch 12 |  iter 1 / 351 | time 0[s] | loss 0.46
# | epoch 12 |  iter 21 / 351 | time 3[s] | loss 0.45
# | epoch 12 |  iter 41 / 351 | time 5[s] | loss 0.45
# | epoch 12 |  iter 61 / 351 | time 8[s] | loss 0.46
# | epoch 12 |  iter 81 / 351 | time 11[s] | loss 0.45
# | epoch 12 |  iter 101 / 351 | time 14[s] | loss 0.46
# | epoch 12 |  iter 121 / 351 | time 17[s] | loss 0.46
# | epoch 12 |  iter 141 / 351 | time 19[s] | loss 0.46
# | epoch 12 |  iter 161 / 351 | time 22[s] | loss 0.45
# | epoch 12 |  iter 181 / 351 | time 25[s] | loss 0.44
# | epoch 12 |  iter 201 / 351 | time 28[s] | loss 0.45
# | epoch 12 |  iter 221 / 351 | time 31[s] | loss 0.44
# | epoch 12 |  iter 241 / 351 | time 34[s] | loss 0.43
# | epoch 12 |  iter 261 / 351 | time 36[s] | loss 0.43
# | epoch 12 |  iter 281 / 351 | time 39[s] | loss 0.44
# | epoch 12 |  iter 301 / 351 | time 42[s] | loss 0.45
# | epoch 12 |  iter 321 / 351 | time 45[s] | loss 0.44
# | epoch 12 |  iter 341 / 351 | time 48[s] | loss 0.43
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# X 1051
# ---
# Q 830+597
# T 1427
# X 1428
# ---
# Q 26+838
# T 864
# X 862
# ---
# Q 143+93
# T 236
# X 237
# ---
# val acc 36.640%
# | epoch 13 |  iter 1 / 351 | time 0[s] | loss 0.41
# | epoch 13 |  iter 21 / 351 | time 3[s] | loss 0.43
# | epoch 13 |  iter 41 / 351 | time 5[s] | loss 0.42
# | epoch 13 |  iter 61 / 351 | time 8[s] | loss 0.42
# | epoch 13 |  iter 81 / 351 | time 11[s] | loss 0.42
# | epoch 13 |  iter 101 / 351 | time 14[s] | loss 0.44
# | epoch 13 |  iter 121 / 351 | time 17[s] | loss 0.43
# | epoch 13 |  iter 141 / 351 | time 20[s] | loss 0.41
# | epoch 13 |  iter 161 / 351 | time 22[s] | loss 0.42
# | epoch 13 |  iter 181 / 351 | time 25[s] | loss 0.42
# | epoch 13 |  iter 201 / 351 | time 28[s] | loss 0.42
# | epoch 13 |  iter 221 / 351 | time 31[s] | loss 0.43
# | epoch 13 |  iter 241 / 351 | time 34[s] | loss 0.43
# | epoch 13 |  iter 261 / 351 | time 37[s] | loss 0.41
# | epoch 13 |  iter 281 / 351 | time 39[s] | loss 0.42
# | epoch 13 |  iter 301 / 351 | time 42[s] | loss 0.41
# | epoch 13 |  iter 321 / 351 | time 45[s] | loss 0.43
# | epoch 13 |  iter 341 / 351 | time 48[s] | loss 0.40
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1140
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 424
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1054
# ---
# Q 830+597
# T 1427
# X 1429
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 239
# ---
# val acc 39.420%
# | epoch 14 |  iter 1 / 351 | time 0[s] | loss 0.41
# | epoch 14 |  iter 21 / 351 | time 2[s] | loss 0.41
# | epoch 14 |  iter 41 / 351 | time 5[s] | loss 0.41
# | epoch 14 |  iter 61 / 351 | time 8[s] | loss 0.40
# | epoch 14 |  iter 81 / 351 | time 11[s] | loss 0.40
# | epoch 14 |  iter 101 / 351 | time 14[s] | loss 0.41
# | epoch 14 |  iter 121 / 351 | time 17[s] | loss 0.39
# | epoch 14 |  iter 141 / 351 | time 19[s] | loss 0.39
# | epoch 14 |  iter 161 / 351 | time 22[s] | loss 0.38
# | epoch 14 |  iter 181 / 351 | time 25[s] | loss 0.38
# | epoch 14 |  iter 201 / 351 | time 28[s] | loss 0.38
# | epoch 14 |  iter 221 / 351 | time 31[s] | loss 0.38
# | epoch 14 |  iter 241 / 351 | time 34[s] | loss 0.39
# | epoch 14 |  iter 261 / 351 | time 36[s] | loss 0.40
# | epoch 14 |  iter 281 / 351 | time 39[s] | loss 0.41
# | epoch 14 |  iter 301 / 351 | time 42[s] | loss 0.39
# | epoch 14 |  iter 321 / 351 | time 45[s] | loss 0.39
# | epoch 14 |  iter 341 / 351 | time 48[s] | loss 0.39
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1137
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 858
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1426
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 235
# ---
# val acc 36.680%
# | epoch 15 |  iter 1 / 351 | time 0[s] | loss 0.38
# | epoch 15 |  iter 21 / 351 | time 3[s] | loss 0.39
# | epoch 15 |  iter 41 / 351 | time 5[s] | loss 0.39
# | epoch 15 |  iter 61 / 351 | time 8[s] | loss 0.38
# | epoch 15 |  iter 81 / 351 | time 11[s] | loss 0.38
# | epoch 15 |  iter 101 / 351 | time 14[s] | loss 0.38
# | epoch 15 |  iter 121 / 351 | time 17[s] | loss 0.38
# | epoch 15 |  iter 141 / 351 | time 19[s] | loss 0.38
# | epoch 15 |  iter 161 / 351 | time 22[s] | loss 0.38
# | epoch 15 |  iter 181 / 351 | time 25[s] | loss 0.38
# | epoch 15 |  iter 201 / 351 | time 28[s] | loss 0.38
# | epoch 15 |  iter 221 / 351 | time 31[s] | loss 0.39
# | epoch 15 |  iter 241 / 351 | time 34[s] | loss 0.38
# | epoch 15 |  iter 261 / 351 | time 36[s] | loss 0.37
# | epoch 15 |  iter 281 / 351 | time 39[s] | loss 0.37
# | epoch 15 |  iter 301 / 351 | time 42[s] | loss 0.39
# | epoch 15 |  iter 321 / 351 | time 45[s] | loss 0.39
# | epoch 15 |  iter 341 / 351 | time 48[s] | loss 0.37
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1137
# ---
# Q 582+84
# T 666
# X 667
# ---
# Q 8+155
# T 163
# X 164
# ---
# Q 367+55
# T 422
# X 420
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1052
# ---
# Q 830+597
# T 1427
# X 1431
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 237
# ---
# val acc 41.100%
# | epoch 16 |  iter 1 / 351 | time 0[s] | loss 0.36
# | epoch 16 |  iter 21 / 351 | time 2[s] | loss 0.36
# | epoch 16 |  iter 41 / 351 | time 5[s] | loss 0.36
# | epoch 16 |  iter 61 / 351 | time 8[s] | loss 0.36
# | epoch 16 |  iter 81 / 351 | time 11[s] | loss 0.37
# | epoch 16 |  iter 101 / 351 | time 14[s] | loss 0.36
# | epoch 16 |  iter 121 / 351 | time 17[s] | loss 0.37
# | epoch 16 |  iter 141 / 351 | time 20[s] | loss 0.36
# | epoch 16 |  iter 161 / 351 | time 22[s] | loss 0.37
# | epoch 16 |  iter 181 / 351 | time 25[s] | loss 0.36
# | epoch 16 |  iter 201 / 351 | time 28[s] | loss 0.38
# | epoch 16 |  iter 221 / 351 | time 31[s] | loss 0.38
# | epoch 16 |  iter 241 / 351 | time 34[s] | loss 0.36
# | epoch 16 |  iter 261 / 351 | time 37[s] | loss 0.35
# | epoch 16 |  iter 281 / 351 | time 39[s] | loss 0.35
# | epoch 16 |  iter 301 / 351 | time 42[s] | loss 0.35
# | epoch 16 |  iter 321 / 351 | time 45[s] | loss 0.35
# | epoch 16 |  iter 341 / 351 | time 48[s] | loss 0.37
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1142
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 858
# ---
# Q 761+292
# T 1053
# X 1054
# ---
# Q 830+597
# T 1427
# X 1430
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 237
# ---
# val acc 42.700%
# | epoch 17 |  iter 1 / 351 | time 0[s] | loss 0.34
# | epoch 17 |  iter 21 / 351 | time 2[s] | loss 0.36
# | epoch 17 |  iter 41 / 351 | time 5[s] | loss 0.36
# | epoch 17 |  iter 61 / 351 | time 8[s] | loss 0.35
# | epoch 17 |  iter 81 / 351 | time 11[s] | loss 0.36
# | epoch 17 |  iter 101 / 351 | time 14[s] | loss 0.34
# | epoch 17 |  iter 121 / 351 | time 17[s] | loss 0.34
# | epoch 17 |  iter 141 / 351 | time 20[s] | loss 0.34
# | epoch 17 |  iter 161 / 351 | time 22[s] | loss 0.34
# | epoch 17 |  iter 181 / 351 | time 25[s] | loss 0.35
# | epoch 17 |  iter 201 / 351 | time 28[s] | loss 0.35
# | epoch 17 |  iter 221 / 351 | time 31[s] | loss 0.34
# | epoch 17 |  iter 241 / 351 | time 34[s] | loss 0.35
# | epoch 17 |  iter 261 / 351 | time 36[s] | loss 0.36
# | epoch 17 |  iter 281 / 351 | time 39[s] | loss 0.37
# | epoch 17 |  iter 301 / 351 | time 42[s] | loss 0.37
# | epoch 17 |  iter 321 / 351 | time 45[s] | loss 0.37
# | epoch 17 |  iter 341 / 351 | time 48[s] | loss 0.36
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1138
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1051
# ---
# Q 830+597
# T 1427
# X 1429
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 42.860%
# | epoch 18 |  iter 1 / 351 | time 0[s] | loss 0.34
# | epoch 18 |  iter 21 / 351 | time 2[s] | loss 0.36
# | epoch 18 |  iter 41 / 351 | time 5[s] | loss 0.35
# | epoch 18 |  iter 61 / 351 | time 8[s] | loss 0.35
# | epoch 18 |  iter 81 / 351 | time 11[s] | loss 0.34
# | epoch 18 |  iter 101 / 351 | time 14[s] | loss 0.34
# | epoch 18 |  iter 121 / 351 | time 17[s] | loss 0.33
# | epoch 18 |  iter 141 / 351 | time 19[s] | loss 0.33
# | epoch 18 |  iter 161 / 351 | time 22[s] | loss 0.34
# | epoch 18 |  iter 181 / 351 | time 25[s] | loss 0.33
# | epoch 18 |  iter 201 / 351 | time 28[s] | loss 0.33
# | epoch 18 |  iter 221 / 351 | time 31[s] | loss 0.33
# | epoch 18 |  iter 241 / 351 | time 34[s] | loss 0.33
# | epoch 18 |  iter 261 / 351 | time 37[s] | loss 0.33
# | epoch 18 |  iter 281 / 351 | time 39[s] | loss 0.33
# | epoch 18 |  iter 301 / 351 | time 42[s] | loss 0.33
# | epoch 18 |  iter 321 / 351 | time 45[s] | loss 0.35
# | epoch 18 |  iter 341 / 351 | time 48[s] | loss 0.35
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1138
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1052
# ---
# Q 830+597
# T 1427
# X 1425
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 237
# ---
# val acc 40.640%
# | epoch 19 |  iter 1 / 351 | time 0[s] | loss 0.34
# | epoch 19 |  iter 21 / 351 | time 2[s] | loss 0.34
# | epoch 19 |  iter 41 / 351 | time 5[s] | loss 0.34
# | epoch 19 |  iter 61 / 351 | time 8[s] | loss 0.34
# | epoch 19 |  iter 81 / 351 | time 11[s] | loss 0.34
# | epoch 19 |  iter 101 / 351 | time 14[s] | loss 0.32
# | epoch 19 |  iter 121 / 351 | time 17[s] | loss 0.31
# | epoch 19 |  iter 141 / 351 | time 19[s] | loss 0.33
# | epoch 19 |  iter 161 / 351 | time 22[s] | loss 0.31
# | epoch 19 |  iter 181 / 351 | time 25[s] | loss 0.30
# | epoch 19 |  iter 201 / 351 | time 28[s] | loss 0.31
# | epoch 19 |  iter 221 / 351 | time 31[s] | loss 0.31
# | epoch 19 |  iter 241 / 351 | time 34[s] | loss 0.32
# | epoch 19 |  iter 261 / 351 | time 36[s] | loss 0.33
# | epoch 19 |  iter 281 / 351 | time 39[s] | loss 0.33
# | epoch 19 |  iter 301 / 351 | time 42[s] | loss 0.32
# | epoch 19 |  iter 321 / 351 | time 45[s] | loss 0.33
# | epoch 19 |  iter 341 / 351 | time 48[s] | loss 0.33
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# X 1140
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 858
# ---
# Q 761+292
# T 1053
# X 1052
# ---
# Q 830+597
# T 1427
# X 1430
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 238
# ---
# val acc 47.540%
# | epoch 20 |  iter 1 / 351 | time 0[s] | loss 0.32
# | epoch 20 |  iter 21 / 351 | time 3[s] | loss 0.35
# | epoch 20 |  iter 41 / 351 | time 5[s] | loss 0.33
# | epoch 20 |  iter 61 / 351 | time 8[s] | loss 0.33
# | epoch 20 |  iter 81 / 351 | time 11[s] | loss 0.31
# | epoch 20 |  iter 101 / 351 | time 14[s] | loss 0.31
# | epoch 20 |  iter 121 / 351 | time 17[s] | loss 0.33
# | epoch 20 |  iter 141 / 351 | time 20[s] | loss 0.32
# | epoch 20 |  iter 161 / 351 | time 22[s] | loss 0.33
# | epoch 20 |  iter 181 / 351 | time 25[s] | loss 0.31
# | epoch 20 |  iter 201 / 351 | time 28[s] | loss 0.30
# | epoch 20 |  iter 221 / 351 | time 31[s] | loss 0.32
# | epoch 20 |  iter 241 / 351 | time 34[s] | loss 0.33
# | epoch 20 |  iter 261 / 351 | time 37[s] | loss 0.35
# | epoch 20 |  iter 281 / 351 | time 39[s] | loss 0.36
# | epoch 20 |  iter 301 / 351 | time 42[s] | loss 0.34
# | epoch 20 |  iter 321 / 351 | time 45[s] | loss 0.32
# | epoch 20 |  iter 341 / 351 | time 48[s] | loss 0.32
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1051
# ---
# Q 830+597
# T 1427
# X 1428
# ---
# Q 26+838
# T 864
# X 862
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 50.000%
# | epoch 21 |  iter 1 / 351 | time 0[s] | loss 0.31
# | epoch 21 |  iter 21 / 351 | time 3[s] | loss 0.31
# | epoch 21 |  iter 41 / 351 | time 5[s] | loss 0.30
# | epoch 21 |  iter 61 / 351 | time 8[s] | loss 0.30
# | epoch 21 |  iter 81 / 351 | time 11[s] | loss 0.32
# | epoch 21 |  iter 101 / 351 | time 14[s] | loss 0.32
# | epoch 21 |  iter 121 / 351 | time 17[s] | loss 0.31
# | epoch 21 |  iter 141 / 351 | time 20[s] | loss 0.30
# | epoch 21 |  iter 161 / 351 | time 22[s] | loss 0.31
# | epoch 21 |  iter 181 / 351 | time 25[s] | loss 0.31
# | epoch 21 |  iter 201 / 351 | time 28[s] | loss 0.31
# | epoch 21 |  iter 221 / 351 | time 31[s] | loss 0.32
# | epoch 21 |  iter 241 / 351 | time 34[s] | loss 0.31
# | epoch 21 |  iter 261 / 351 | time 37[s] | loss 0.29
# | epoch 21 |  iter 281 / 351 | time 40[s] | loss 0.30
# | epoch 21 |  iter 301 / 351 | time 42[s] | loss 0.29
# | epoch 21 |  iter 321 / 351 | time 45[s] | loss 0.29
# | epoch 21 |  iter 341 / 351 | time 48[s] | loss 0.29
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# X 859
# ---
# Q 761+292
# T 1053
# X 1052
# ---
# Q 830+597
# T 1427
# X 1428
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 50.940%
# | epoch 22 |  iter 1 / 351 | time 0[s] | loss 0.32
# | epoch 22 |  iter 21 / 351 | time 3[s] | loss 0.29
# | epoch 22 |  iter 41 / 351 | time 5[s] | loss 0.28
# | epoch 22 |  iter 61 / 351 | time 8[s] | loss 0.29
# | epoch 22 |  iter 81 / 351 | time 11[s] | loss 0.29
# | epoch 22 |  iter 101 / 351 | time 14[s] | loss 0.28
# | epoch 22 |  iter 121 / 351 | time 17[s] | loss 0.29
# | epoch 22 |  iter 141 / 351 | time 20[s] | loss 0.31
# | epoch 22 |  iter 161 / 351 | time 22[s] | loss 0.31
# | epoch 22 |  iter 181 / 351 | time 25[s] | loss 0.30
# | epoch 22 |  iter 201 / 351 | time 28[s] | loss 0.28
# | epoch 22 |  iter 221 / 351 | time 31[s] | loss 0.32
# | epoch 22 |  iter 241 / 351 | time 34[s] | loss 0.33
# | epoch 22 |  iter 261 / 351 | time 37[s] | loss 0.32
# | epoch 22 |  iter 281 / 351 | time 39[s] | loss 0.31
# | epoch 22 |  iter 301 / 351 | time 42[s] | loss 0.30
# | epoch 22 |  iter 321 / 351 | time 45[s] | loss 0.29
# | epoch 22 |  iter 341 / 351 | time 48[s] | loss 0.31
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1430
# ---
# Q 26+838
# T 864
# X 865
# ---
# Q 143+93
# T 236
# X 238
# ---
# val acc 47.700%
# | epoch 23 |  iter 1 / 351 | time 0[s] | loss 0.31
# | epoch 23 |  iter 21 / 351 | time 3[s] | loss 0.31
# | epoch 23 |  iter 41 / 351 | time 5[s] | loss 0.28
# | epoch 23 |  iter 61 / 351 | time 8[s] | loss 0.28
# | epoch 23 |  iter 81 / 351 | time 11[s] | loss 0.29
# | epoch 23 |  iter 101 / 351 | time 14[s] | loss 0.27
# | epoch 23 |  iter 121 / 351 | time 17[s] | loss 0.28
# | epoch 23 |  iter 141 / 351 | time 20[s] | loss 0.28
# | epoch 23 |  iter 161 / 351 | time 22[s] | loss 0.30
# | epoch 23 |  iter 181 / 351 | time 25[s] | loss 0.30
# | epoch 23 |  iter 201 / 351 | time 28[s] | loss 0.29
# | epoch 23 |  iter 221 / 351 | time 31[s] | loss 0.29
# | epoch 23 |  iter 241 / 351 | time 34[s] | loss 0.28
# | epoch 23 |  iter 261 / 351 | time 37[s] | loss 0.28
# | epoch 23 |  iter 281 / 351 | time 39[s] | loss 0.30
# | epoch 23 |  iter 301 / 351 | time 42[s] | loss 0.29
# | epoch 23 |  iter 321 / 351 | time 45[s] | loss 0.29
# | epoch 23 |  iter 341 / 351 | time 48[s] | loss 0.28
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1142
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 858
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1429
# ---
# Q 26+838
# T 864
# X 866
# ---
# Q 143+93
# T 236
# X 238
# ---
# val acc 45.180%
# | epoch 24 |  iter 1 / 351 | time 0[s] | loss 0.31
# | epoch 24 |  iter 21 / 351 | time 3[s] | loss 0.29
# | epoch 24 |  iter 41 / 351 | time 5[s] | loss 0.28
# | epoch 24 |  iter 61 / 351 | time 8[s] | loss 0.29
# | epoch 24 |  iter 81 / 351 | time 11[s] | loss 0.30
# | epoch 24 |  iter 101 / 351 | time 14[s] | loss 0.29
# | epoch 24 |  iter 121 / 351 | time 17[s] | loss 0.29
# | epoch 24 |  iter 141 / 351 | time 20[s] | loss 0.29
# | epoch 24 |  iter 161 / 351 | time 22[s] | loss 0.28
# | epoch 24 |  iter 181 / 351 | time 25[s] | loss 0.29
# | epoch 24 |  iter 201 / 351 | time 28[s] | loss 0.28
# | epoch 24 |  iter 221 / 351 | time 31[s] | loss 0.28
# | epoch 24 |  iter 241 / 351 | time 34[s] | loss 0.29
# | epoch 24 |  iter 261 / 351 | time 37[s] | loss 0.29
# | epoch 24 |  iter 281 / 351 | time 39[s] | loss 0.29
# | epoch 24 |  iter 301 / 351 | time 42[s] | loss 0.28
# | epoch 24 |  iter 321 / 351 | time 45[s] | loss 0.27
# | epoch 24 |  iter 341 / 351 | time 48[s] | loss 0.29
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# X 421
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# X 1054
# ---
# Q 830+597
# T 1427
# X 1428
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 237
# ---
# val acc 51.820%
# | epoch 25 |  iter 1 / 351 | time 0[s] | loss 0.29
# | epoch 25 |  iter 21 / 351 | time 3[s] | loss 0.29
# | epoch 25 |  iter 41 / 351 | time 5[s] | loss 0.28
# | epoch 25 |  iter 61 / 351 | time 8[s] | loss 0.26
# | epoch 25 |  iter 81 / 351 | time 11[s] | loss 0.26
# | epoch 25 |  iter 101 / 351 | time 14[s] | loss 0.27
# | epoch 25 |  iter 121 / 351 | time 17[s] | loss 0.29
# | epoch 25 |  iter 141 / 351 | time 20[s] | loss 0.28
# | epoch 25 |  iter 161 / 351 | time 22[s] | loss 0.28
# | epoch 25 |  iter 181 / 351 | time 25[s] | loss 0.28
# | epoch 25 |  iter 201 / 351 | time 28[s] | loss 0.27
# | epoch 25 |  iter 221 / 351 | time 31[s] | loss 0.29
# | epoch 25 |  iter 241 / 351 | time 34[s] | loss 0.27
# | epoch 25 |  iter 261 / 351 | time 37[s] | loss 0.28
# | epoch 25 |  iter 281 / 351 | time 39[s] | loss 0.28
# | epoch 25 |  iter 301 / 351 | time 42[s] | loss 0.27
# | epoch 25 |  iter 321 / 351 | time 45[s] | loss 0.28
# | epoch 25 |  iter 341 / 351 | time 48[s] | loss 0.28
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1140
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 856
# ---
# Q 761+292
# T 1053
# X 1052
# ---
# Q 830+597
# T 1427
# X 1426
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 54.100%

# %% [markdown]
# ### 7.4.2 覗き見（Peeky）
#
# Encoderは入力文（問題文）を固定長のベクトルhに変換する。
# そのhがDecoderにとって唯一の情報源である。
# しかし、現状のseq2seqは最初の時刻のLSTMレイヤのみがベクトルhを利用している（図7-25）。
# この重要な情報であるhをもっと活用する改善が図7-26。

# %%
class PeekyDecoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(H + D, 4 * H) / np.sqrt(H + D)).astype('f') # DがH+Dになった
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H + H, V) / np.sqrt(H + H)).astype('f') # HがH+Hになった
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []
        for layer in (self.embed, self.lstm, self.affine):
            self.params += layer.params
            self.grads += layer.grads
        self.cache = None

    def forward(self, xs, h):
        N, T = xs.shape
        N, H = h.shape

        self.lstm.set_state(h)

        out = self.embed.forward(xs)
        hs = np.repeat(h, T, axis=0).reshape(N, T, H) # この辺が追加
        out = np.concatenate((hs, out), axis=2)

        out = self.lstm.forward(out)
        out = np.concatenate((hs, out), axis=2)

        score = self.affine.forward(out)
        self.cache = H
        return score

    def backward(self, dscore):
        H = self.cache

        dout = self.affine.backward(dscore)
        dout, dhs0 = dout[:, :, H:], dout[:, :, :H]
        dout = self.lstm.backward(dout)
        dembed, dhs1 = dout[:, :, H:], dout[:, :, :H]
        self.embed.backward(dembed)

        dhs = dhs0 + dhs1
        dh = self.lstm.dh + np.sum(dhs, axis=1)
        return dh

    def generate(self, h, start_id, sample_size):
        sampled = []
        char_id = start_id
        self.lstm.set_state(h)

        H = h.shape[1]
        peeky_h = h.reshape(1, 1, H)
        for _ in range(sample_size):
            x = np.array([char_id]).reshape((1, 1))
            out = self.embed.forward(x)

            out = np.concatenate((peeky_h, out), axis=2)
            out = self.lstm.forward(out)
            out = np.concatenate((peeky_h, out), axis=2)
            score = self.affine.forward(out)

            char_id = np.argmax(score.flatten())
            sampled.append(char_id)

        return sampled


class PeekySeq2seq(Seq2seq):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = Encoder(V, D, H)
        self.decoder = PeekyDecoder(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads

# %%
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
#from seq2seq import Seq2seq
#from peeky_seq2seq import PeekySeq2seq


# データセットの読み込み
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

# Reverse input? =================================================
is_reverse = True
if is_reverse:
    x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]
# ================================================================

# ハイパーパラメータの設定
vocab_size = len(char_to_id)
wordvec_size = 16
hideen_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

# Normal or Peeky? ==============================================
# model = Seq2seq(vocab_size, wordvec_size, hideen_size)
model = PeekySeq2seq(vocab_size, wordvec_size, hideen_size) # ここを変えた
# ================================================================
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1,
                batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct,
                                    id_to_char, verbose, is_reverse)

    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('val acc %.3f%%' % (acc * 100))
# Out:
# | epoch 1 |  iter 1 / 351 | time 0[s] | loss 2.57
# | epoch 1 |  iter 21 / 351 | time 3[s] | loss 2.48
# | epoch 1 |  iter 41 / 351 | time 6[s] | loss 2.20
# | epoch 1 |  iter 61 / 351 | time 9[s] | loss 1.99
# | epoch 1 |  iter 81 / 351 | time 12[s] | loss 1.89
# | epoch 1 |  iter 101 / 351 | time 15[s] | loss 1.82
# | epoch 1 |  iter 121 / 351 | time 18[s] | loss 1.82
# | epoch 1 |  iter 141 / 351 | time 21[s] | loss 1.80
# | epoch 1 |  iter 161 / 351 | time 24[s] | loss 1.79
# | epoch 1 |  iter 181 / 351 | time 27[s] | loss 1.78
# | epoch 1 |  iter 201 / 351 | time 30[s] | loss 1.77
# | epoch 1 |  iter 221 / 351 | time 33[s] | loss 1.76
# | epoch 1 |  iter 241 / 351 | time 37[s] | loss 1.76
# | epoch 1 |  iter 261 / 351 | time 40[s] | loss 1.75
# | epoch 1 |  iter 281 / 351 | time 43[s] | loss 1.74
# | epoch 1 |  iter 301 / 351 | time 46[s] | loss 1.74
# | epoch 1 |  iter 321 / 351 | time 49[s] | loss 1.73
# | epoch 1 |  iter 341 / 351 | time 52[s] | loss 1.73
# Q 77+85
# T 162
# X 100
# ---
# Q 975+164
# T 1139
# X 1013
# ---
# Q 582+84
# T 666
# X 102
# ---
# Q 8+155
# T 163
# X 100
# ---
# Q 367+55
# T 422
# X 1023
# ---
# Q 600+257
# T 857
# X 1023
# ---
# Q 761+292
# T 1053
# X 1023
# ---
# Q 830+597
# T 1427
# X 1111
# ---
# Q 26+838
# T 864
# X 102
# ---
# Q 143+93
# T 236
# X 102
# ---
# val acc 0.280%
# | epoch 2 |  iter 1 / 351 | time 0[s] | loss 1.71
# | epoch 2 |  iter 21 / 351 | time 3[s] | loss 1.71
# | epoch 2 |  iter 41 / 351 | time 6[s] | loss 1.71
# | epoch 2 |  iter 61 / 351 | time 9[s] | loss 1.71
# | epoch 2 |  iter 81 / 351 | time 12[s] | loss 1.70
# | epoch 2 |  iter 101 / 351 | time 15[s] | loss 1.68
# | epoch 2 |  iter 121 / 351 | time 18[s] | loss 1.69
# | epoch 2 |  iter 141 / 351 | time 21[s] | loss 1.68
# | epoch 2 |  iter 161 / 351 | time 24[s] | loss 1.67
# | epoch 2 |  iter 181 / 351 | time 27[s] | loss 1.67
# | epoch 2 |  iter 201 / 351 | time 31[s] | loss 1.65
# | epoch 2 |  iter 221 / 351 | time 34[s] | loss 1.65
# | epoch 2 |  iter 241 / 351 | time 37[s] | loss 1.65
# | epoch 2 |  iter 261 / 351 | time 40[s] | loss 1.63
# | epoch 2 |  iter 281 / 351 | time 43[s] | loss 1.62
# | epoch 2 |  iter 301 / 351 | time 46[s] | loss 1.61
# | epoch 2 |  iter 321 / 351 | time 49[s] | loss 1.61
# | epoch 2 |  iter 341 / 351 | time 52[s] | loss 1.60
# Q 77+85
# T 162
# X 100
# ---
# Q 975+164
# T 1139
# X 1200
# ---
# Q 582+84
# T 666
# X 690
# ---
# Q 8+155
# T 163
# X 100
# ---
# Q 367+55
# T 422
# X 690
# ---
# Q 600+257
# T 857
# X 999
# ---
# Q 761+292
# T 1053
# X 1029
# ---
# Q 830+597
# T 1427
# X 1240
# ---
# Q 26+838
# T 864
# X 792
# ---
# Q 143+93
# T 236
# X 290
# ---
# val acc 0.400%
# | epoch 3 |  iter 1 / 351 | time 0[s] | loss 1.58
# | epoch 3 |  iter 21 / 351 | time 3[s] | loss 1.59
# | epoch 3 |  iter 41 / 351 | time 6[s] | loss 1.58
# | epoch 3 |  iter 61 / 351 | time 9[s] | loss 1.56
# | epoch 3 |  iter 81 / 351 | time 12[s] | loss 1.55
# | epoch 3 |  iter 101 / 351 | time 15[s] | loss 1.53
# | epoch 3 |  iter 121 / 351 | time 18[s] | loss 1.51
# | epoch 3 |  iter 141 / 351 | time 22[s] | loss 1.50
# | epoch 3 |  iter 161 / 351 | time 25[s] | loss 1.49
# | epoch 3 |  iter 181 / 351 | time 28[s] | loss 1.47
# | epoch 3 |  iter 201 / 351 | time 31[s] | loss 1.46
# | epoch 3 |  iter 221 / 351 | time 34[s] | loss 1.43
# | epoch 3 |  iter 241 / 351 | time 37[s] | loss 1.42
# | epoch 3 |  iter 261 / 351 | time 40[s] | loss 1.41
# | epoch 3 |  iter 281 / 351 | time 44[s] | loss 1.39
# | epoch 3 |  iter 301 / 351 | time 47[s] | loss 1.37
# | epoch 3 |  iter 321 / 351 | time 50[s] | loss 1.36
# | epoch 3 |  iter 341 / 351 | time 53[s] | loss 1.35
# Q 77+85
# T 162
# X 154
# ---
# Q 975+164
# T 1139
# X 1033
# ---
# Q 582+84
# T 666
# X 644
# ---
# Q 8+155
# T 163
# X 161
# ---
# Q 367+55
# T 422
# X 433
# ---
# Q 600+257
# T 857
# X 818
# ---
# Q 761+292
# T 1053
# X 1018
# ---
# Q 830+597
# T 1427
# X 1344
# ---
# Q 26+838
# T 864
# X 834
# ---
# Q 143+93
# T 236
# X 211
# ---
# val acc 1.600%
# | epoch 4 |  iter 1 / 351 | time 0[s] | loss 1.32
# | epoch 4 |  iter 21 / 351 | time 3[s] | loss 1.32
# | epoch 4 |  iter 41 / 351 | time 6[s] | loss 1.30
# | epoch 4 |  iter 61 / 351 | time 9[s] | loss 1.30
# | epoch 4 |  iter 81 / 351 | time 12[s] | loss 1.28
# | epoch 4 |  iter 101 / 351 | time 15[s] | loss 1.27
# | epoch 4 |  iter 121 / 351 | time 19[s] | loss 1.25
# | epoch 4 |  iter 141 / 351 | time 22[s] | loss 1.24
# | epoch 4 |  iter 161 / 351 | time 25[s] | loss 1.22
# | epoch 4 |  iter 181 / 351 | time 28[s] | loss 1.21
# | epoch 4 |  iter 201 / 351 | time 31[s] | loss 1.20
# | epoch 4 |  iter 221 / 351 | time 34[s] | loss 1.20
# | epoch 4 |  iter 241 / 351 | time 37[s] | loss 1.17
# | epoch 4 |  iter 261 / 351 | time 41[s] | loss 1.16
# | epoch 4 |  iter 281 / 351 | time 44[s] | loss 1.14
# | epoch 4 |  iter 301 / 351 | time 47[s] | loss 1.12
# | epoch 4 |  iter 321 / 351 | time 50[s] | loss 1.11
# | epoch 4 |  iter 341 / 351 | time 53[s] | loss 1.10
# Q 77+85
# T 162
# X 158
# ---
# Q 975+164
# T 1139
# X 1123
# ---
# Q 582+84
# T 666
# X 657
# ---
# Q 8+155
# T 163
# X 165
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# X 777
# ---
# Q 761+292
# T 1053
# X 1023
# ---
# Q 830+597
# T 1427
# X 1388
# ---
# Q 26+838
# T 864
# X 887
# ---
# Q 143+93
# T 236
# X 223
# ---
# val acc 5.140%
# | epoch 5 |  iter 1 / 351 | time 0[s] | loss 1.08
# | epoch 5 |  iter 21 / 351 | time 3[s] | loss 1.07
# | epoch 5 |  iter 41 / 351 | time 6[s] | loss 1.05
# | epoch 5 |  iter 61 / 351 | time 9[s] | loss 1.04
# | epoch 5 |  iter 81 / 351 | time 12[s] | loss 1.02
# | epoch 5 |  iter 101 / 351 | time 15[s] | loss 1.01
# | epoch 5 |  iter 121 / 351 | time 19[s] | loss 1.00
# | epoch 5 |  iter 141 / 351 | time 22[s] | loss 0.99
# | epoch 5 |  iter 161 / 351 | time 25[s] | loss 0.99
# | epoch 5 |  iter 181 / 351 | time 28[s] | loss 0.96
# | epoch 5 |  iter 201 / 351 | time 31[s] | loss 0.95
# | epoch 5 |  iter 221 / 351 | time 34[s] | loss 0.94
# | epoch 5 |  iter 241 / 351 | time 37[s] | loss 0.92
# | epoch 5 |  iter 261 / 351 | time 41[s] | loss 0.91
# | epoch 5 |  iter 281 / 351 | time 44[s] | loss 0.90
# | epoch 5 |  iter 301 / 351 | time 47[s] | loss 0.89
# | epoch 5 |  iter 321 / 351 | time 50[s] | loss 0.88
# | epoch 5 |  iter 341 / 351 | time 53[s] | loss 0.87
# Q 77+85
# T 162
# X 160
# ---
# Q 975+164
# T 1139
# X 1135
# ---
# Q 582+84
# T 666
# X 668
# ---
# Q 8+155
# T 163
# X 169
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 861
# ---
# Q 761+292
# T 1053
# X 1045
# ---
# Q 830+597
# T 1427
# X 1324
# ---
# Q 26+838
# T 864
# X 861
# ---
# Q 143+93
# T 236
# X 239
# ---
# val acc 9.380%
# | epoch 6 |  iter 1 / 351 | time 0[s] | loss 0.90
# | epoch 6 |  iter 21 / 351 | time 3[s] | loss 0.86
# | epoch 6 |  iter 41 / 351 | time 6[s] | loss 0.83
# | epoch 6 |  iter 61 / 351 | time 9[s] | loss 0.84
# | epoch 6 |  iter 81 / 351 | time 12[s] | loss 0.82
# | epoch 6 |  iter 101 / 351 | time 15[s] | loss 0.81
# | epoch 6 |  iter 121 / 351 | time 19[s] | loss 0.80
# | epoch 6 |  iter 141 / 351 | time 22[s] | loss 0.79
# | epoch 6 |  iter 161 / 351 | time 25[s] | loss 0.78
# | epoch 6 |  iter 181 / 351 | time 28[s] | loss 0.77
# | epoch 6 |  iter 201 / 351 | time 31[s] | loss 0.76
# | epoch 6 |  iter 221 / 351 | time 34[s] | loss 0.76
# | epoch 6 |  iter 241 / 351 | time 37[s] | loss 0.74
# | epoch 6 |  iter 261 / 351 | time 41[s] | loss 0.74
# | epoch 6 |  iter 281 / 351 | time 44[s] | loss 0.73
# | epoch 6 |  iter 301 / 351 | time 47[s] | loss 0.72
# | epoch 6 |  iter 321 / 351 | time 50[s] | loss 0.72
# | epoch 6 |  iter 341 / 351 | time 53[s] | loss 0.71
# Q 77+85
# T 162
# X 163
# ---
# Q 975+164
# T 1139
# X 1138
# ---
# Q 582+84
# T 666
# X 668
# ---
# Q 8+155
# T 163
# X 166
# ---
# Q 367+55
# T 422
# X 423
# ---
# Q 600+257
# T 857
# X 858
# ---
# Q 761+292
# T 1053
# X 1048
# ---
# Q 830+597
# T 1427
# X 1428
# ---
# Q 26+838
# T 864
# X 873
# ---
# Q 143+93
# T 236
# X 239
# ---
# val acc 15.040%
# | epoch 7 |  iter 1 / 351 | time 0[s] | loss 0.68
# | epoch 7 |  iter 21 / 351 | time 3[s] | loss 0.69
# | epoch 7 |  iter 41 / 351 | time 6[s] | loss 0.67
# | epoch 7 |  iter 61 / 351 | time 9[s] | loss 0.66
# | epoch 7 |  iter 81 / 351 | time 12[s] | loss 0.66
# | epoch 7 |  iter 101 / 351 | time 16[s] | loss 0.65
# | epoch 7 |  iter 121 / 351 | time 19[s] | loss 0.65
# | epoch 7 |  iter 141 / 351 | time 22[s] | loss 0.64
# | epoch 7 |  iter 161 / 351 | time 25[s] | loss 0.63
# | epoch 7 |  iter 181 / 351 | time 28[s] | loss 0.61
# | epoch 7 |  iter 201 / 351 | time 31[s] | loss 0.61
# | epoch 7 |  iter 221 / 351 | time 34[s] | loss 0.60
# | epoch 7 |  iter 241 / 351 | time 38[s] | loss 0.57
# | epoch 7 |  iter 261 / 351 | time 41[s] | loss 0.57
# | epoch 7 |  iter 281 / 351 | time 44[s] | loss 0.57
# | epoch 7 |  iter 301 / 351 | time 47[s] | loss 0.55
# | epoch 7 |  iter 321 / 351 | time 50[s] | loss 0.54
# | epoch 7 |  iter 341 / 351 | time 53[s] | loss 0.53
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 665
# ---
# Q 8+155
# T 163
# X 156
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# X 858
# ---
# Q 761+292
# T 1053
# X 1052
# ---
# Q 830+597
# T 1427
# X 1428
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# X 235
# ---
# val acc 39.100%
# | epoch 8 |  iter 1 / 351 | time 0[s] | loss 0.51
# | epoch 8 |  iter 21 / 351 | time 3[s] | loss 0.50
# | epoch 8 |  iter 41 / 351 | time 6[s] | loss 0.49
# | epoch 8 |  iter 61 / 351 | time 9[s] | loss 0.48
# | epoch 8 |  iter 81 / 351 | time 12[s] | loss 0.47
# | epoch 8 |  iter 101 / 351 | time 15[s] | loss 0.46
# | epoch 8 |  iter 121 / 351 | time 19[s] | loss 0.46
# | epoch 8 |  iter 141 / 351 | time 22[s] | loss 0.44
# | epoch 8 |  iter 161 / 351 | time 25[s] | loss 0.41
# | epoch 8 |  iter 181 / 351 | time 28[s] | loss 0.42
# | epoch 8 |  iter 201 / 351 | time 31[s] | loss 0.41
# | epoch 8 |  iter 221 / 351 | time 34[s] | loss 0.40
# | epoch 8 |  iter 241 / 351 | time 38[s] | loss 0.39
# | epoch 8 |  iter 261 / 351 | time 41[s] | loss 0.37
# | epoch 8 |  iter 281 / 351 | time 44[s] | loss 0.36
# | epoch 8 |  iter 301 / 351 | time 47[s] | loss 0.36
# | epoch 8 |  iter 321 / 351 | time 50[s] | loss 0.35
# | epoch 8 |  iter 341 / 351 | time 53[s] | loss 0.34
# Q 77+85
# T 162
# X 161
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 657
# ---
# Q 8+155
# T 163
# X 155
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# X 1438
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 65.060%
# | epoch 9 |  iter 1 / 351 | time 0[s] | loss 0.32
# | epoch 9 |  iter 21 / 351 | time 3[s] | loss 0.31
# | epoch 9 |  iter 41 / 351 | time 6[s] | loss 0.31
# | epoch 9 |  iter 61 / 351 | time 9[s] | loss 0.31
# | epoch 9 |  iter 81 / 351 | time 12[s] | loss 0.29
# | epoch 9 |  iter 101 / 351 | time 15[s] | loss 0.29
# | epoch 9 |  iter 121 / 351 | time 19[s] | loss 0.29
# | epoch 9 |  iter 141 / 351 | time 22[s] | loss 0.27
# | epoch 9 |  iter 161 / 351 | time 25[s] | loss 0.27
# | epoch 9 |  iter 181 / 351 | time 28[s] | loss 0.26
# | epoch 9 |  iter 201 / 351 | time 31[s] | loss 0.25
# | epoch 9 |  iter 221 / 351 | time 34[s] | loss 0.25
# | epoch 9 |  iter 241 / 351 | time 38[s] | loss 0.24
# | epoch 9 |  iter 261 / 351 | time 41[s] | loss 0.24
# | epoch 9 |  iter 281 / 351 | time 44[s] | loss 0.23
# | epoch 9 |  iter 301 / 351 | time 47[s] | loss 0.22
# | epoch 9 |  iter 321 / 351 | time 50[s] | loss 0.22
# | epoch 9 |  iter 341 / 351 | time 53[s] | loss 0.21
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1140
# ---
# Q 582+84
# T 666
# X 657
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 83.300%
# | epoch 10 |  iter 1 / 351 | time 0[s] | loss 0.22
# | epoch 10 |  iter 21 / 351 | time 3[s] | loss 0.20
# | epoch 10 |  iter 41 / 351 | time 6[s] | loss 0.20
# | epoch 10 |  iter 61 / 351 | time 9[s] | loss 0.20
# | epoch 10 |  iter 81 / 351 | time 12[s] | loss 0.18
# | epoch 10 |  iter 101 / 351 | time 16[s] | loss 0.17
# | epoch 10 |  iter 121 / 351 | time 19[s] | loss 0.18
# | epoch 10 |  iter 141 / 351 | time 22[s] | loss 0.17
# | epoch 10 |  iter 161 / 351 | time 25[s] | loss 0.17
# | epoch 10 |  iter 181 / 351 | time 28[s] | loss 0.17
# | epoch 10 |  iter 201 / 351 | time 32[s] | loss 0.17
# | epoch 10 |  iter 221 / 351 | time 35[s] | loss 0.16
# | epoch 10 |  iter 241 / 351 | time 38[s] | loss 0.15
# | epoch 10 |  iter 261 / 351 | time 41[s] | loss 0.15
# | epoch 10 |  iter 281 / 351 | time 44[s] | loss 0.15
# | epoch 10 |  iter 301 / 351 | time 47[s] | loss 0.15
# | epoch 10 |  iter 321 / 351 | time 51[s] | loss 0.14
# | epoch 10 |  iter 341 / 351 | time 54[s] | loss 0.14
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# X 656
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 88.380%
# | epoch 11 |  iter 1 / 351 | time 0[s] | loss 0.13
# | epoch 11 |  iter 21 / 351 | time 3[s] | loss 0.13
# | epoch 11 |  iter 41 / 351 | time 6[s] | loss 0.13
# | epoch 11 |  iter 61 / 351 | time 9[s] | loss 0.12
# | epoch 11 |  iter 81 / 351 | time 12[s] | loss 0.12
# | epoch 11 |  iter 101 / 351 | time 15[s] | loss 0.12
# | epoch 11 |  iter 121 / 351 | time 19[s] | loss 0.11
# | epoch 11 |  iter 141 / 351 | time 22[s] | loss 0.12
# | epoch 11 |  iter 161 / 351 | time 25[s] | loss 0.11
# | epoch 11 |  iter 181 / 351 | time 28[s] | loss 0.11
# | epoch 11 |  iter 201 / 351 | time 31[s] | loss 0.12
# | epoch 11 |  iter 221 / 351 | time 35[s] | loss 0.11
# | epoch 11 |  iter 241 / 351 | time 38[s] | loss 0.11
# | epoch 11 |  iter 261 / 351 | time 41[s] | loss 0.10
# | epoch 11 |  iter 281 / 351 | time 44[s] | loss 0.10
# | epoch 11 |  iter 301 / 351 | time 47[s] | loss 0.10
# | epoch 11 |  iter 321 / 351 | time 50[s] | loss 0.09
# | epoch 11 |  iter 341 / 351 | time 54[s] | loss 0.09
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 90.940%
# | epoch 12 |  iter 1 / 351 | time 0[s] | loss 0.09
# | epoch 12 |  iter 21 / 351 | time 3[s] | loss 0.09
# | epoch 12 |  iter 41 / 351 | time 6[s] | loss 0.09
# | epoch 12 |  iter 61 / 351 | time 9[s] | loss 0.09
# | epoch 12 |  iter 81 / 351 | time 12[s] | loss 0.09
# | epoch 12 |  iter 101 / 351 | time 16[s] | loss 0.08
# | epoch 12 |  iter 121 / 351 | time 19[s] | loss 0.08
# | epoch 12 |  iter 141 / 351 | time 22[s] | loss 0.08
# | epoch 12 |  iter 161 / 351 | time 25[s] | loss 0.08
# | epoch 12 |  iter 181 / 351 | time 28[s] | loss 0.08
# | epoch 12 |  iter 201 / 351 | time 31[s] | loss 0.08
# | epoch 12 |  iter 221 / 351 | time 35[s] | loss 0.09
# | epoch 12 |  iter 241 / 351 | time 38[s] | loss 0.09
# | epoch 12 |  iter 261 / 351 | time 41[s] | loss 0.09
# | epoch 12 |  iter 281 / 351 | time 44[s] | loss 0.08
# | epoch 12 |  iter 301 / 351 | time 47[s] | loss 0.08
# | epoch 12 |  iter 321 / 351 | time 50[s] | loss 0.07
# | epoch 12 |  iter 341 / 351 | time 54[s] | loss 0.08
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 92.240%
# | epoch 13 |  iter 1 / 351 | time 0[s] | loss 0.07
# | epoch 13 |  iter 21 / 351 | time 3[s] | loss 0.07
# | epoch 13 |  iter 41 / 351 | time 6[s] | loss 0.07
# | epoch 13 |  iter 61 / 351 | time 9[s] | loss 0.07
# | epoch 13 |  iter 81 / 351 | time 12[s] | loss 0.06
# | epoch 13 |  iter 101 / 351 | time 16[s] | loss 0.06
# | epoch 13 |  iter 121 / 351 | time 19[s] | loss 0.07
# | epoch 13 |  iter 141 / 351 | time 22[s] | loss 0.06
# | epoch 13 |  iter 161 / 351 | time 25[s] | loss 0.06
# | epoch 13 |  iter 181 / 351 | time 28[s] | loss 0.06
# | epoch 13 |  iter 201 / 351 | time 31[s] | loss 0.06
# | epoch 13 |  iter 221 / 351 | time 35[s] | loss 0.06
# | epoch 13 |  iter 241 / 351 | time 38[s] | loss 0.06
# | epoch 13 |  iter 261 / 351 | time 41[s] | loss 0.06
# | epoch 13 |  iter 281 / 351 | time 44[s] | loss 0.06
# | epoch 13 |  iter 301 / 351 | time 47[s] | loss 0.05
# | epoch 13 |  iter 321 / 351 | time 50[s] | loss 0.05
# | epoch 13 |  iter 341 / 351 | time 54[s] | loss 0.06
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 94.380%
# | epoch 14 |  iter 1 / 351 | time 0[s] | loss 0.05
# | epoch 14 |  iter 21 / 351 | time 3[s] | loss 0.05
# | epoch 14 |  iter 41 / 351 | time 6[s] | loss 0.05
# | epoch 14 |  iter 61 / 351 | time 9[s] | loss 0.05
# | epoch 14 |  iter 81 / 351 | time 12[s] | loss 0.05
# | epoch 14 |  iter 101 / 351 | time 16[s] | loss 0.05
# | epoch 14 |  iter 121 / 351 | time 19[s] | loss 0.05
# | epoch 14 |  iter 141 / 351 | time 22[s] | loss 0.05
# | epoch 14 |  iter 161 / 351 | time 25[s] | loss 0.05
# | epoch 14 |  iter 181 / 351 | time 28[s] | loss 0.05
# | epoch 14 |  iter 201 / 351 | time 32[s] | loss 0.05
# | epoch 14 |  iter 221 / 351 | time 35[s] | loss 0.06
# | epoch 14 |  iter 241 / 351 | time 38[s] | loss 0.06
# | epoch 14 |  iter 261 / 351 | time 41[s] | loss 0.08
# | epoch 14 |  iter 281 / 351 | time 44[s] | loss 0.07
# | epoch 14 |  iter 301 / 351 | time 47[s] | loss 0.07
# | epoch 14 |  iter 321 / 351 | time 51[s] | loss 0.05
# | epoch 14 |  iter 341 / 351 | time 54[s] | loss 0.04
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 95.320%
# | epoch 15 |  iter 1 / 351 | time 0[s] | loss 0.04
# | epoch 15 |  iter 21 / 351 | time 3[s] | loss 0.04
# | epoch 15 |  iter 41 / 351 | time 6[s] | loss 0.04
# | epoch 15 |  iter 61 / 351 | time 9[s] | loss 0.05
# | epoch 15 |  iter 81 / 351 | time 13[s] | loss 0.04
# | epoch 15 |  iter 101 / 351 | time 16[s] | loss 0.04
# | epoch 15 |  iter 121 / 351 | time 19[s] | loss 0.04
# | epoch 15 |  iter 141 / 351 | time 22[s] | loss 0.04
# | epoch 15 |  iter 161 / 351 | time 25[s] | loss 0.04
# | epoch 15 |  iter 181 / 351 | time 28[s] | loss 0.04
# | epoch 15 |  iter 201 / 351 | time 32[s] | loss 0.04
# | epoch 15 |  iter 221 / 351 | time 35[s] | loss 0.04
# | epoch 15 |  iter 241 / 351 | time 38[s] | loss 0.04
# | epoch 15 |  iter 261 / 351 | time 41[s] | loss 0.05
# | epoch 15 |  iter 281 / 351 | time 44[s] | loss 0.05
# | epoch 15 |  iter 301 / 351 | time 48[s] | loss 0.05
# | epoch 15 |  iter 321 / 351 | time 51[s] | loss 0.04
# | epoch 15 |  iter 341 / 351 | time 54[s] | loss 0.04
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# X 1149
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 94.180%
# | epoch 16 |  iter 1 / 351 | time 0[s] | loss 0.04
# | epoch 16 |  iter 21 / 351 | time 3[s] | loss 0.05
# | epoch 16 |  iter 41 / 351 | time 6[s] | loss 0.05
# | epoch 16 |  iter 61 / 351 | time 9[s] | loss 0.05
# | epoch 16 |  iter 81 / 351 | time 12[s] | loss 0.04
# | epoch 16 |  iter 101 / 351 | time 16[s] | loss 0.04
# | epoch 16 |  iter 121 / 351 | time 19[s] | loss 0.04
# | epoch 16 |  iter 141 / 351 | time 22[s] | loss 0.04
# | epoch 16 |  iter 161 / 351 | time 25[s] | loss 0.04
# | epoch 16 |  iter 181 / 351 | time 28[s] | loss 0.04
# | epoch 16 |  iter 201 / 351 | time 32[s] | loss 0.04
# | epoch 16 |  iter 221 / 351 | time 35[s] | loss 0.04
# | epoch 16 |  iter 241 / 351 | time 38[s] | loss 0.04
# | epoch 16 |  iter 261 / 351 | time 41[s] | loss 0.04
# | epoch 16 |  iter 281 / 351 | time 44[s] | loss 0.04
# | epoch 16 |  iter 301 / 351 | time 47[s] | loss 0.04
# | epoch 16 |  iter 321 / 351 | time 51[s] | loss 0.04
# | epoch 16 |  iter 341 / 351 | time 54[s] | loss 0.04
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 95.940%
# | epoch 17 |  iter 1 / 351 | time 0[s] | loss 0.03
# | epoch 17 |  iter 21 / 351 | time 3[s] | loss 0.04
# | epoch 17 |  iter 41 / 351 | time 6[s] | loss 0.04
# | epoch 17 |  iter 61 / 351 | time 9[s] | loss 0.04
# | epoch 17 |  iter 81 / 351 | time 12[s] | loss 0.03
# | epoch 17 |  iter 101 / 351 | time 16[s] | loss 0.03
# | epoch 17 |  iter 121 / 351 | time 19[s] | loss 0.03
# | epoch 17 |  iter 141 / 351 | time 22[s] | loss 0.03
# | epoch 17 |  iter 161 / 351 | time 25[s] | loss 0.03
# | epoch 17 |  iter 181 / 351 | time 28[s] | loss 0.03
# | epoch 17 |  iter 201 / 351 | time 31[s] | loss 0.03
# | epoch 17 |  iter 221 / 351 | time 35[s] | loss 0.03
# | epoch 17 |  iter 241 / 351 | time 38[s] | loss 0.03
# | epoch 17 |  iter 261 / 351 | time 41[s] | loss 0.03
# | epoch 17 |  iter 281 / 351 | time 44[s] | loss 0.03
# | epoch 17 |  iter 301 / 351 | time 47[s] | loss 0.03
# | epoch 17 |  iter 321 / 351 | time 50[s] | loss 0.03
# | epoch 17 |  iter 341 / 351 | time 54[s] | loss 0.04
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 94.320%
# | epoch 18 |  iter 1 / 351 | time 0[s] | loss 0.04
# | epoch 18 |  iter 21 / 351 | time 3[s] | loss 0.04
# | epoch 18 |  iter 41 / 351 | time 6[s] | loss 0.05
# | epoch 18 |  iter 61 / 351 | time 9[s] | loss 0.06
# | epoch 18 |  iter 81 / 351 | time 12[s] | loss 0.06
# | epoch 18 |  iter 101 / 351 | time 16[s] | loss 0.05
# | epoch 18 |  iter 121 / 351 | time 19[s] | loss 0.04
# | epoch 18 |  iter 141 / 351 | time 22[s] | loss 0.03
# | epoch 18 |  iter 161 / 351 | time 25[s] | loss 0.03
# | epoch 18 |  iter 181 / 351 | time 28[s] | loss 0.03
# | epoch 18 |  iter 201 / 351 | time 31[s] | loss 0.03
# | epoch 18 |  iter 221 / 351 | time 35[s] | loss 0.02
# | epoch 18 |  iter 241 / 351 | time 38[s] | loss 0.02
# | epoch 18 |  iter 261 / 351 | time 41[s] | loss 0.02
# | epoch 18 |  iter 281 / 351 | time 44[s] | loss 0.02
# | epoch 18 |  iter 301 / 351 | time 47[s] | loss 0.02
# | epoch 18 |  iter 321 / 351 | time 51[s] | loss 0.02
# | epoch 18 |  iter 341 / 351 | time 54[s] | loss 0.03
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 95.620%
# | epoch 19 |  iter 1 / 351 | time 0[s] | loss 0.02
# | epoch 19 |  iter 21 / 351 | time 3[s] | loss 0.03
# | epoch 19 |  iter 41 / 351 | time 6[s] | loss 0.02
# | epoch 19 |  iter 61 / 351 | time 9[s] | loss 0.02
# | epoch 19 |  iter 81 / 351 | time 12[s] | loss 0.02
# | epoch 19 |  iter 101 / 351 | time 16[s] | loss 0.02
# | epoch 19 |  iter 121 / 351 | time 19[s] | loss 0.02
# | epoch 19 |  iter 141 / 351 | time 22[s] | loss 0.02
# | epoch 19 |  iter 161 / 351 | time 25[s] | loss 0.02
# | epoch 19 |  iter 181 / 351 | time 28[s] | loss 0.02
# | epoch 19 |  iter 201 / 351 | time 31[s] | loss 0.03
# | epoch 19 |  iter 221 / 351 | time 35[s] | loss 0.02
# | epoch 19 |  iter 241 / 351 | time 38[s] | loss 0.03
# | epoch 19 |  iter 261 / 351 | time 41[s] | loss 0.04
# | epoch 19 |  iter 281 / 351 | time 44[s] | loss 0.04
# | epoch 19 |  iter 301 / 351 | time 47[s] | loss 0.04
# | epoch 19 |  iter 321 / 351 | time 50[s] | loss 0.03
# | epoch 19 |  iter 341 / 351 | time 54[s] | loss 0.03
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 96.420%
# | epoch 20 |  iter 1 / 351 | time 0[s] | loss 0.03
# | epoch 20 |  iter 21 / 351 | time 3[s] | loss 0.03
# | epoch 20 |  iter 41 / 351 | time 6[s] | loss 0.02
# | epoch 20 |  iter 61 / 351 | time 9[s] | loss 0.03
# | epoch 20 |  iter 81 / 351 | time 12[s] | loss 0.03
# | epoch 20 |  iter 101 / 351 | time 16[s] | loss 0.03
# | epoch 20 |  iter 121 / 351 | time 19[s] | loss 0.02
# | epoch 20 |  iter 141 / 351 | time 22[s] | loss 0.02
# | epoch 20 |  iter 161 / 351 | time 25[s] | loss 0.02
# | epoch 20 |  iter 181 / 351 | time 28[s] | loss 0.03
# | epoch 20 |  iter 201 / 351 | time 32[s] | loss 0.03
# | epoch 20 |  iter 221 / 351 | time 35[s] | loss 0.03
# | epoch 20 |  iter 241 / 351 | time 38[s] | loss 0.02
# | epoch 20 |  iter 261 / 351 | time 41[s] | loss 0.02
# | epoch 20 |  iter 281 / 351 | time 44[s] | loss 0.02
# | epoch 20 |  iter 301 / 351 | time 47[s] | loss 0.03
# | epoch 20 |  iter 321 / 351 | time 51[s] | loss 0.02
# | epoch 20 |  iter 341 / 351 | time 54[s] | loss 0.03
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 95.100%
# | epoch 21 |  iter 1 / 351 | time 0[s] | loss 0.04
# | epoch 21 |  iter 21 / 351 | time 3[s] | loss 0.03
# | epoch 21 |  iter 41 / 351 | time 6[s] | loss 0.03
# | epoch 21 |  iter 61 / 351 | time 9[s] | loss 0.02
# | epoch 21 |  iter 81 / 351 | time 12[s] | loss 0.02
# | epoch 21 |  iter 101 / 351 | time 16[s] | loss 0.02
# | epoch 21 |  iter 121 / 351 | time 19[s] | loss 0.02
# | epoch 21 |  iter 141 / 351 | time 22[s] | loss 0.02
# | epoch 21 |  iter 161 / 351 | time 25[s] | loss 0.02
# | epoch 21 |  iter 181 / 351 | time 28[s] | loss 0.02
# | epoch 21 |  iter 201 / 351 | time 31[s] | loss 0.02
# | epoch 21 |  iter 221 / 351 | time 35[s] | loss 0.02
# | epoch 21 |  iter 241 / 351 | time 38[s] | loss 0.02
# | epoch 21 |  iter 261 / 351 | time 41[s] | loss 0.02
# | epoch 21 |  iter 281 / 351 | time 44[s] | loss 0.03
# | epoch 21 |  iter 301 / 351 | time 47[s] | loss 0.03
# | epoch 21 |  iter 321 / 351 | time 50[s] | loss 0.03
# | epoch 21 |  iter 341 / 351 | time 54[s] | loss 0.03
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# X 162
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 96.760%
# | epoch 22 |  iter 1 / 351 | time 0[s] | loss 0.02
# | epoch 22 |  iter 21 / 351 | time 3[s] | loss 0.03
# | epoch 22 |  iter 41 / 351 | time 6[s] | loss 0.03
# | epoch 22 |  iter 61 / 351 | time 9[s] | loss 0.03
# | epoch 22 |  iter 81 / 351 | time 12[s] | loss 0.03
# | epoch 22 |  iter 101 / 351 | time 16[s] | loss 0.03
# | epoch 22 |  iter 121 / 351 | time 19[s] | loss 0.03
# | epoch 22 |  iter 141 / 351 | time 22[s] | loss 0.02
# | epoch 22 |  iter 161 / 351 | time 25[s] | loss 0.02
# | epoch 22 |  iter 181 / 351 | time 28[s] | loss 0.01
# | epoch 22 |  iter 201 / 351 | time 31[s] | loss 0.01
# | epoch 22 |  iter 221 / 351 | time 35[s] | loss 0.01
# | epoch 22 |  iter 241 / 351 | time 38[s] | loss 0.01
# | epoch 22 |  iter 261 / 351 | time 41[s] | loss 0.01
# | epoch 22 |  iter 281 / 351 | time 44[s] | loss 0.01
# | epoch 22 |  iter 301 / 351 | time 47[s] | loss 0.01
# | epoch 22 |  iter 321 / 351 | time 50[s] | loss 0.01
# | epoch 22 |  iter 341 / 351 | time 54[s] | loss 0.01
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 98.560%
# | epoch 23 |  iter 1 / 351 | time 0[s] | loss 0.01
# | epoch 23 |  iter 21 / 351 | time 3[s] | loss 0.01
# | epoch 23 |  iter 41 / 351 | time 6[s] | loss 0.01
# | epoch 23 |  iter 61 / 351 | time 9[s] | loss 0.01
# | epoch 23 |  iter 81 / 351 | time 12[s] | loss 0.01
# | epoch 23 |  iter 101 / 351 | time 16[s] | loss 0.01
# | epoch 23 |  iter 121 / 351 | time 19[s] | loss 0.01
# | epoch 23 |  iter 141 / 351 | time 22[s] | loss 0.01
# | epoch 23 |  iter 161 / 351 | time 25[s] | loss 0.01
# | epoch 23 |  iter 181 / 351 | time 28[s] | loss 0.01
# | epoch 23 |  iter 201 / 351 | time 32[s] | loss 0.02
# | epoch 23 |  iter 221 / 351 | time 35[s] | loss 0.03
# | epoch 23 |  iter 241 / 351 | time 38[s] | loss 0.05
# | epoch 23 |  iter 261 / 351 | time 41[s] | loss 0.07
# | epoch 23 |  iter 281 / 351 | time 45[s] | loss 0.06
# | epoch 23 |  iter 301 / 351 | time 48[s] | loss 0.05
# | epoch 23 |  iter 321 / 351 | time 51[s] | loss 0.05
# | epoch 23 |  iter 341 / 351 | time 54[s] | loss 0.05
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 93.120%
# | epoch 24 |  iter 1 / 351 | time 0[s] | loss 0.03
# | epoch 24 |  iter 21 / 351 | time 3[s] | loss 0.04
# | epoch 24 |  iter 41 / 351 | time 6[s] | loss 0.03
# | epoch 24 |  iter 61 / 351 | time 9[s] | loss 0.02
# | epoch 24 |  iter 81 / 351 | time 12[s] | loss 0.02
# | epoch 24 |  iter 101 / 351 | time 16[s] | loss 0.02
# | epoch 24 |  iter 121 / 351 | time 19[s] | loss 0.02
# | epoch 24 |  iter 141 / 351 | time 22[s] | loss 0.02
# | epoch 24 |  iter 161 / 351 | time 25[s] | loss 0.01
# | epoch 24 |  iter 181 / 351 | time 28[s] | loss 0.01
# | epoch 24 |  iter 201 / 351 | time 32[s] | loss 0.01
# | epoch 24 |  iter 221 / 351 | time 35[s] | loss 0.02
# | epoch 24 |  iter 241 / 351 | time 38[s] | loss 0.01
# | epoch 24 |  iter 261 / 351 | time 41[s] | loss 0.01
# | epoch 24 |  iter 281 / 351 | time 44[s] | loss 0.01
# | epoch 24 |  iter 301 / 351 | time 47[s] | loss 0.01
# | epoch 24 |  iter 321 / 351 | time 51[s] | loss 0.01
# | epoch 24 |  iter 341 / 351 | time 54[s] | loss 0.01
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 99.440%
# | epoch 25 |  iter 1 / 351 | time 0[s] | loss 0.01
# | epoch 25 |  iter 21 / 351 | time 3[s] | loss 0.01
# | epoch 25 |  iter 41 / 351 | time 6[s] | loss 0.01
# | epoch 25 |  iter 61 / 351 | time 9[s] | loss 0.01
# | epoch 25 |  iter 81 / 351 | time 12[s] | loss 0.01
# | epoch 25 |  iter 101 / 351 | time 16[s] | loss 0.01
# | epoch 25 |  iter 121 / 351 | time 19[s] | loss 0.01
# | epoch 25 |  iter 141 / 351 | time 22[s] | loss 0.01
# | epoch 25 |  iter 161 / 351 | time 25[s] | loss 0.01
# | epoch 25 |  iter 181 / 351 | time 28[s] | loss 0.01
# | epoch 25 |  iter 201 / 351 | time 32[s] | loss 0.01
# | epoch 25 |  iter 221 / 351 | time 35[s] | loss 0.01
# | epoch 25 |  iter 241 / 351 | time 38[s] | loss 0.01
# | epoch 25 |  iter 261 / 351 | time 41[s] | loss 0.01
# | epoch 25 |  iter 281 / 351 | time 44[s] | loss 0.01
# | epoch 25 |  iter 301 / 351 | time 47[s] | loss 0.01
# | epoch 25 |  iter 321 / 351 | time 51[s] | loss 0.01
# | epoch 25 |  iter 341 / 351 | time 54[s] | loss 0.01
# Q 77+85
# T 162
# O 162
# ---
# Q 975+164
# T 1139
# O 1139
# ---
# Q 582+84
# T 666
# O 666
# ---
# Q 8+155
# T 163
# O 163
# ---
# Q 367+55
# T 422
# O 422
# ---
# Q 600+257
# T 857
# O 857
# ---
# Q 761+292
# T 1053
# O 1053
# ---
# Q 830+597
# T 1427
# O 1427
# ---
# Q 26+838
# T 864
# O 864
# ---
# Q 143+93
# T 236
# O 236
# ---
# val acc 98.940%

# %% [markdown]
# ReverseとPeekyが共に効果的に働いていることが分かる。
# ここで行った改良は小さな改良に過ぎず、次章ではseq2seqに大きな改良を加える。
# それはAttentitonと呼ばれるテクニックで、seq2seqを劇的に進化させることができる！（土田さんの解説に期待が高まる）
#
# Peekyを用いることで、重みパラメータが増え、計算量が増加していることには注意が必要である。
# また、seq2seqの精度はハイパーパラメータの調整で大きく変わる。
